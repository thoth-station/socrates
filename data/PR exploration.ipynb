# %%
import pandas as pd

# %%
prs = pd.read_json("PullRequest.json").T
prs
# Out:
#                                                    title  \
# 26100  bug 1949306: add e2e test to block usage of re...
# 26099  bug 1951705: allow HighOverallControlPlaneCPU ...
# 26098  refactor TestMultipleImageChangeBuildTriggers,...
# 26097  WIP: monitor: Move "crashlooping pods" test to...
# 26096                  Bug 1949050: fix images.sh script
# ...                                                  ...
# 5                          Add examples for pod creation
# 4               [WIP] Added project template json-schema
# 3                      Added etcd folder into .gitignore
# 2                            Add alpha API documentation
# 1                  Add link to GOPATH doc and fixup typo
#
#                                                     body size      created_by  \
# 26100  Right now this is set to flake in CI and provi...  XXL         deads2k
# 26099  adding the alert in https://github.com/openshi...   XS         deads2k
# 26098  So reworking this test was motivated by 2 thin...  XXL     gabemontero
# 26097  Crashlooping, long pulls, and other container ...    L  smarterclayton
# 26096  This is a followup to https://github.com/opens...    S         soltysh
# ...                                                  ...  ...             ...
# 5                                                   None    M        jwforres
# 4                                                           L         mfojtik
# 3                                                          XS         mfojtik
# 2                            Merge of csrwng/oo-api-v3\n  XXL          csrwng
# 1                                                   None   XS        jwforres
#
#        created_at   closed_at              closed_by   merged_at  \
# 26100  1619104429  1619253940  openshift-merge-robot  1619253940
# 26099  1619091511  1619113470  openshift-merge-robot  1619113470
# 26098  1619037132        None            gabemontero        None
# 26097  1619035732        None                   None        None
# 26096  1618993979  1619069721  openshift-merge-robot  1619069721
# ...           ...         ...                    ...         ...
# 5      1407846787  1407866827         smarterclayton  1407866827
# 4      1407843204  1408087830                mfojtik        None
# 3      1407836378  1407866813         smarterclayton  1407866813
# 2      1407834992  1407844533                 danmcp  1407844533
# 1      1407759383  1407759502         smarterclayton  1407759502
#
#       commits_number changed_files_number  \
# 26100              2                  135
# 26099              1                    1
# 26098              2                  118
# 26097              1                    5
# 26096              1                    2
# ...              ...                  ...
# 5                  1                    7
# 4                  1                    1
# 3                  1                    1
# 2                  1                   54
# 1                  1                    1
#
#                                             interactions  \
# 26100  {'deads2k': 1, 'openshift-ci-robot': 307, 'stt...
# 26099  {'openshift-ci-robot': 508, 'deads2k': 43, 'op...
# 26098  {'gabemontero': 194, 'openshift-ci-robot': 89,...
# 26097  {'openshift-ci-robot': 68, 'smarterclayton': 1...
# 26096  {'openshift-ci-robot': 279, 'soltysh': 2, 'ope...
# ...                                                  ...
# 5      {'jwforres': 31, 'VojtechVitek': 18, 'ncdc': 3...
# 4                     {'VojtechVitek': 1, 'mfojtik': 30}
# 3                                         {'mfojtik': 4}
# 2                                         {'mfojtik': 1}
# 1                                                     {}
#
#                                                  reviews  \
# 26100                                                 {}
# 26099                                                 {}
# 26098                                                 {}
# 26097                                                 {}
# 26096  {'641526396': {'author': 'adambkaplan', 'words...
# ...                                                  ...
# 5                                                     {}
# 4                                                     {}
# 3                                                     {}
# 2                                                     {}
# 1                                                     {}
#
#                                                   labels  \
# 26100  [approved, bugzilla/severity-urgent, bugzilla/...
# 26099  [approved, bugzilla/severity-high, bugzilla/va...
# 26098                 [do-not-merge/hold, vendor-update]
# 26097          [approved, do-not-merge/work-in-progress]
# 26096  [approved, bugzilla/severity-high, bugzilla/va...
# ...                                                  ...
# 5                                                     []
# 4                                                     []
# 3                                                     []
# 2                                                     []
# 1                                                     []
#
#                                                  commits  \
# 26100  [13b0e99d5f35d85998af9f07eb0c5b7d6fcc0dd0, 0c3...
# 26099         [7bc10c83eea29010f3b735c41847d43a992f606c]
# 26098  [2d329e88159f7af1594054ce467cfdb3c320b612, e7e...
# 26097         [95756458436b0e79a7ea779c6b0f6de2e4ee5a1f]
# 26096         [06830a927241a44ae24e9a4b5b2ac75f666d36bc]
# ...                                                  ...
# 5             [cfbef75adee9cb5208d7e4c58ac8b1bf4dbdc1aa]
# 4             [8af28a76da8bf8fd0293501bca49b423e652005e]
# 3             [46c010676eb2655d256f29e2413f97aeeff17310]
# 2             [24acb7993293e311e8c1f76f4b17791998c2f391]
# 1             [3c15fd6dd7cee58393feb786fd7876b6f22fe9b5]
#
#                                            changed_files
# 26100  [go.mod, go.sum, test/extended/apiserver/api_r...
# 26099           [test/extended/prometheus/prometheus.go]
# 26098  [go.mod, go.sum, test/extended/images/imagecha...
# 26097  [pkg/monitor/pod.go, pkg/synthetictests/event_...
# 26096  [test/extended/testdata/bindata.go, test/exten...
# ...                                                  ...
# 5      [README.md, examples/hello-openshift/Dockerfil...
# 4                          [api/doc/project.json_schema]
# 3                                           [.gitignore]
# 2      [api/README.md, api/build_flow.odg, api/doc/co...
# 1                                            [README.md]
#
# [17183 rows x 15 columns]

# %%
prs_cleared = prs.drop(["commits_number"], axis=1)

# %%
prs_cleared
# Out:
#                                                    title  \
# 26100  bug 1949306: add e2e test to block usage of re...
# 26099  bug 1951705: allow HighOverallControlPlaneCPU ...
# 26098  refactor TestMultipleImageChangeBuildTriggers,...
# 26097  WIP: monitor: Move "crashlooping pods" test to...
# 26096                  Bug 1949050: fix images.sh script
# ...                                                  ...
# 5                          Add examples for pod creation
# 4               [WIP] Added project template json-schema
# 3                      Added etcd folder into .gitignore
# 2                            Add alpha API documentation
# 1                  Add link to GOPATH doc and fixup typo
#
#                                                     body size      created_by  \
# 26100  Right now this is set to flake in CI and provi...  XXL         deads2k
# 26099  adding the alert in https://github.com/openshi...   XS         deads2k
# 26098  So reworking this test was motivated by 2 thin...  XXL     gabemontero
# 26097  Crashlooping, long pulls, and other container ...    L  smarterclayton
# 26096  This is a followup to https://github.com/opens...    S         soltysh
# ...                                                  ...  ...             ...
# 5                                                   None    M        jwforres
# 4                                                           L         mfojtik
# 3                                                          XS         mfojtik
# 2                            Merge of csrwng/oo-api-v3\n  XXL          csrwng
# 1                                                   None   XS        jwforres
#
#        created_at   closed_at              closed_by   merged_at  \
# 26100  1619104429  1619253940  openshift-merge-robot  1619253940
# 26099  1619091511  1619113470  openshift-merge-robot  1619113470
# 26098  1619037132        None            gabemontero        None
# 26097  1619035732        None                   None        None
# 26096  1618993979  1619069721  openshift-merge-robot  1619069721
# ...           ...         ...                    ...         ...
# 5      1407846787  1407866827         smarterclayton  1407866827
# 4      1407843204  1408087830                mfojtik        None
# 3      1407836378  1407866813         smarterclayton  1407866813
# 2      1407834992  1407844533                 danmcp  1407844533
# 1      1407759383  1407759502         smarterclayton  1407759502
#
#       changed_files_number                                       interactions  \
# 26100                  135  {'deads2k': 1, 'openshift-ci-robot': 307, 'stt...
# 26099                    1  {'openshift-ci-robot': 508, 'deads2k': 43, 'op...
# 26098                  118  {'gabemontero': 194, 'openshift-ci-robot': 89,...
# 26097                    5  {'openshift-ci-robot': 68, 'smarterclayton': 1...
# 26096                    2  {'openshift-ci-robot': 279, 'soltysh': 2, 'ope...
# ...                    ...                                                ...
# 5                        7  {'jwforres': 31, 'VojtechVitek': 18, 'ncdc': 3...
# 4                        1                 {'VojtechVitek': 1, 'mfojtik': 30}
# 3                        1                                     {'mfojtik': 4}
# 2                       54                                     {'mfojtik': 1}
# 1                        1                                                 {}
#
#                                                  reviews  \
# 26100                                                 {}
# 26099                                                 {}
# 26098                                                 {}
# 26097                                                 {}
# 26096  {'641526396': {'author': 'adambkaplan', 'words...
# ...                                                  ...
# 5                                                     {}
# 4                                                     {}
# 3                                                     {}
# 2                                                     {}
# 1                                                     {}
#
#                                                   labels  \
# 26100  [approved, bugzilla/severity-urgent, bugzilla/...
# 26099  [approved, bugzilla/severity-high, bugzilla/va...
# 26098                 [do-not-merge/hold, vendor-update]
# 26097          [approved, do-not-merge/work-in-progress]
# 26096  [approved, bugzilla/severity-high, bugzilla/va...
# ...                                                  ...
# 5                                                     []
# 4                                                     []
# 3                                                     []
# 2                                                     []
# 1                                                     []
#
#                                                  commits  \
# 26100  [13b0e99d5f35d85998af9f07eb0c5b7d6fcc0dd0, 0c3...
# 26099         [7bc10c83eea29010f3b735c41847d43a992f606c]
# 26098  [2d329e88159f7af1594054ce467cfdb3c320b612, e7e...
# 26097         [95756458436b0e79a7ea779c6b0f6de2e4ee5a1f]
# 26096         [06830a927241a44ae24e9a4b5b2ac75f666d36bc]
# ...                                                  ...
# 5             [cfbef75adee9cb5208d7e4c58ac8b1bf4dbdc1aa]
# 4             [8af28a76da8bf8fd0293501bca49b423e652005e]
# 3             [46c010676eb2655d256f29e2413f97aeeff17310]
# 2             [24acb7993293e311e8c1f76f4b17791998c2f391]
# 1             [3c15fd6dd7cee58393feb786fd7876b6f22fe9b5]
#
#                                            changed_files
# 26100  [go.mod, go.sum, test/extended/apiserver/api_r...
# 26099           [test/extended/prometheus/prometheus.go]
# 26098  [go.mod, go.sum, test/extended/images/imagecha...
# 26097  [pkg/monitor/pod.go, pkg/synthetictests/event_...
# 26096  [test/extended/testdata/bindata.go, test/exten...
# ...                                                  ...
# 5      [README.md, examples/hello-openshift/Dockerfil...
# 4                          [api/doc/project.json_schema]
# 3                                           [.gitignore]
# 2      [api/README.md, api/build_flow.odg, api/doc/co...
# 1                                            [README.md]
#
# [17183 rows x 14 columns]

# %%
prs_filtered = prs_cleared.drop(["interactions", "reviews", "labels",], axis=1)

# %%
pd.to_datetime(prs_filtered.created_at.astype(int))
# Out:
# 26100   1970-01-01 00:00:01.619104429
# 26099   1970-01-01 00:00:01.619091511
# 26098   1970-01-01 00:00:01.619037132
# 26097   1970-01-01 00:00:01.619035732
# 26096   1970-01-01 00:00:01.618993979
#                      ...
# 5       1970-01-01 00:00:01.407846787
# 4       1970-01-01 00:00:01.407843204
# 3       1970-01-01 00:00:01.407836378
# 2       1970-01-01 00:00:01.407834992
# 1       1970-01-01 00:00:01.407759383
# Name: created_at, Length: 17183, dtype: datetime64[ns]

# %%
prs_filtered.created_at = pd.to_datetime(prs_filtered.created_at, unit="s")

# %%
prs_filtered = prs_filtered.sort_index()

# %%
prs_filtered.created_at.plot()
# Out:
# <AxesSubplot:>

# %%
prs_filtered["counts"] = 1
prs_filtered.counts = prs_filtered.counts.cumsum()

# %%
prs_filtered.plot("created_at", "counts")
# Out:
# <AxesSubplot:xlabel='created_at'>

# %%
from datetime import datetime

# %%
prs_filtered["day"] = prs_filtered.created_at.dt.normalize()
prs_filtered
# Out:
#                                                    title  \
# 1                  Add link to GOPATH doc and fixup typo
# 2                            Add alpha API documentation
# 3                      Added etcd folder into .gitignore
# 4               [WIP] Added project template json-schema
# 5                          Add examples for pod creation
# ...                                                  ...
# 26096                  Bug 1949050: fix images.sh script
# 26097  WIP: monitor: Move "crashlooping pods" test to...
# 26098  refactor TestMultipleImageChangeBuildTriggers,...
# 26099  bug 1951705: allow HighOverallControlPlaneCPU ...
# 26100  bug 1949306: add e2e test to block usage of re...
#
#                                                     body size      created_by  \
# 1                                                   None   XS        jwforres
# 2                            Merge of csrwng/oo-api-v3\n  XXL          csrwng
# 3                                                          XS         mfojtik
# 4                                                           L         mfojtik
# 5                                                   None    M        jwforres
# ...                                                  ...  ...             ...
# 26096  This is a followup to https://github.com/opens...    S         soltysh
# 26097  Crashlooping, long pulls, and other container ...    L  smarterclayton
# 26098  So reworking this test was motivated by 2 thin...  XXL     gabemontero
# 26099  adding the alert in https://github.com/openshi...   XS         deads2k
# 26100  Right now this is set to flake in CI and provi...  XXL         deads2k
#
#                created_at   closed_at              closed_by   merged_at  \
# 1     2014-08-11 12:16:23  1407759502         smarterclayton  1407759502
# 2     2014-08-12 09:16:32  1407844533                 danmcp  1407844533
# 3     2014-08-12 09:39:38  1407866813         smarterclayton  1407866813
# 4     2014-08-12 11:33:24  1408087830                mfojtik        None
# 5     2014-08-12 12:33:07  1407866827         smarterclayton  1407866827
# ...                   ...         ...                    ...         ...
# 26096 2021-04-21 08:32:59  1619069721  openshift-merge-robot  1619069721
# 26097 2021-04-21 20:08:52        None                   None        None
# 26098 2021-04-21 20:32:12        None            gabemontero        None
# 26099 2021-04-22 11:38:31  1619113470  openshift-merge-robot  1619113470
# 26100 2021-04-22 15:13:49  1619253940  openshift-merge-robot  1619253940
#
#       changed_files_number                                            commits  \
# 1                        1         [3c15fd6dd7cee58393feb786fd7876b6f22fe9b5]
# 2                       54         [24acb7993293e311e8c1f76f4b17791998c2f391]
# 3                        1         [46c010676eb2655d256f29e2413f97aeeff17310]
# 4                        1         [8af28a76da8bf8fd0293501bca49b423e652005e]
# 5                        7         [cfbef75adee9cb5208d7e4c58ac8b1bf4dbdc1aa]
# ...                    ...                                                ...
# 26096                    2         [06830a927241a44ae24e9a4b5b2ac75f666d36bc]
# 26097                    5         [95756458436b0e79a7ea779c6b0f6de2e4ee5a1f]
# 26098                  118  [2d329e88159f7af1594054ce467cfdb3c320b612, e7e...
# 26099                    1         [7bc10c83eea29010f3b735c41847d43a992f606c]
# 26100                  135  [13b0e99d5f35d85998af9f07eb0c5b7d6fcc0dd0, 0c3...
#
#                                            changed_files  counts        day
# 1                                            [README.md]       1 2014-08-11
# 2      [api/README.md, api/build_flow.odg, api/doc/co...       2 2014-08-12
# 3                                           [.gitignore]       3 2014-08-12
# 4                          [api/doc/project.json_schema]       4 2014-08-12
# 5      [README.md, examples/hello-openshift/Dockerfil...       5 2014-08-12
# ...                                                  ...     ...        ...
# 26096  [test/extended/testdata/bindata.go, test/exten...   17179 2021-04-21
# 26097  [pkg/monitor/pod.go, pkg/synthetictests/event_...   17180 2021-04-21
# 26098  [go.mod, go.sum, test/extended/images/imagecha...   17181 2021-04-21
# 26099           [test/extended/prometheus/prometheus.go]   17182 2021-04-22
# 26100  [go.mod, go.sum, test/extended/apiserver/api_r...   17183 2021-04-22
#
# [17183 rows x 13 columns]

# %%
prs_filtered["one_vec"] = 1
prs_filtered.groupby("day").agg({"one_vec":"sum"}).plot()
# Out:
# <AxesSubplot:xlabel='day'>

# %%
import numpy as np
prs_nan_free = prs_filtered.fillna(value=np.nan)
prs_nan_free
# Out:
#                                                    title  \
# 1                  Add link to GOPATH doc and fixup typo
# 2                            Add alpha API documentation
# 3                      Added etcd folder into .gitignore
# 4               [WIP] Added project template json-schema
# 5                          Add examples for pod creation
# ...                                                  ...
# 26096                  Bug 1949050: fix images.sh script
# 26097  WIP: monitor: Move "crashlooping pods" test to...
# 26098  refactor TestMultipleImageChangeBuildTriggers,...
# 26099  bug 1951705: allow HighOverallControlPlaneCPU ...
# 26100  bug 1949306: add e2e test to block usage of re...
#
#                                                     body size      created_by  \
# 1                                                    NaN   XS        jwforres
# 2                            Merge of csrwng/oo-api-v3\n  XXL          csrwng
# 3                                                          XS         mfojtik
# 4                                                           L         mfojtik
# 5                                                    NaN    M        jwforres
# ...                                                  ...  ...             ...
# 26096  This is a followup to https://github.com/opens...    S         soltysh
# 26097  Crashlooping, long pulls, and other container ...    L  smarterclayton
# 26098  So reworking this test was motivated by 2 thin...  XXL     gabemontero
# 26099  adding the alert in https://github.com/openshi...   XS         deads2k
# 26100  Right now this is set to flake in CI and provi...  XXL         deads2k
#
#                created_at     closed_at              closed_by     merged_at  \
# 1     2014-08-11 12:16:23  1.407760e+09         smarterclayton  1.407760e+09
# 2     2014-08-12 09:16:32  1.407845e+09                 danmcp  1.407845e+09
# 3     2014-08-12 09:39:38  1.407867e+09         smarterclayton  1.407867e+09
# 4     2014-08-12 11:33:24  1.408088e+09                mfojtik           NaN
# 5     2014-08-12 12:33:07  1.407867e+09         smarterclayton  1.407867e+09
# ...                   ...           ...                    ...           ...
# 26096 2021-04-21 08:32:59  1.619070e+09  openshift-merge-robot  1.619070e+09
# 26097 2021-04-21 20:08:52           NaN                    NaN           NaN
# 26098 2021-04-21 20:32:12           NaN            gabemontero           NaN
# 26099 2021-04-22 11:38:31  1.619113e+09  openshift-merge-robot  1.619113e+09
# 26100 2021-04-22 15:13:49  1.619254e+09  openshift-merge-robot  1.619254e+09
#
#        changed_files_number  \
# 1                         1
# 2                        54
# 3                         1
# 4                         1
# 5                         7
# ...                     ...
# 26096                     2
# 26097                     5
# 26098                   118
# 26099                     1
# 26100                   135
#
#                                                  commits  \
# 1             [3c15fd6dd7cee58393feb786fd7876b6f22fe9b5]
# 2             [24acb7993293e311e8c1f76f4b17791998c2f391]
# 3             [46c010676eb2655d256f29e2413f97aeeff17310]
# 4             [8af28a76da8bf8fd0293501bca49b423e652005e]
# 5             [cfbef75adee9cb5208d7e4c58ac8b1bf4dbdc1aa]
# ...                                                  ...
# 26096         [06830a927241a44ae24e9a4b5b2ac75f666d36bc]
# 26097         [95756458436b0e79a7ea779c6b0f6de2e4ee5a1f]
# 26098  [2d329e88159f7af1594054ce467cfdb3c320b612, e7e...
# 26099         [7bc10c83eea29010f3b735c41847d43a992f606c]
# 26100  [13b0e99d5f35d85998af9f07eb0c5b7d6fcc0dd0, 0c3...
#
#                                            changed_files  counts        day  \
# 1                                            [README.md]       1 2014-08-11
# 2      [api/README.md, api/build_flow.odg, api/doc/co...       2 2014-08-12
# 3                                           [.gitignore]       3 2014-08-12
# 4                          [api/doc/project.json_schema]       4 2014-08-12
# 5      [README.md, examples/hello-openshift/Dockerfil...       5 2014-08-12
# ...                                                  ...     ...        ...
# 26096  [test/extended/testdata/bindata.go, test/exten...   17179 2021-04-21
# 26097  [pkg/monitor/pod.go, pkg/synthetictests/event_...   17180 2021-04-21
# 26098  [go.mod, go.sum, test/extended/images/imagecha...   17181 2021-04-21
# 26099           [test/extended/prometheus/prometheus.go]   17182 2021-04-22
# 26100  [go.mod, go.sum, test/extended/apiserver/api_r...   17183 2021-04-22
#
#        one_vec
# 1            1
# 2            1
# 3            1
# 4            1
# 5            1
# ...        ...
# 26096        1
# 26097        1
# 26098        1
# 26099        1
# 26100        1
#
# [17183 rows x 14 columns]

# %%
closed = ~prs_nan_free['closed_at'].isnull()
merged = prs_nan_free['merged_at'].isnull()

# %%
closed
# Out:
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
#          ...
# 26096     True
# 26097    False
# 26098    False
# 26099     True
# 26100     True
# Name: closed_at, Length: 17183, dtype: bool

# %%
merged
# Out:
# 1        False
# 2        False
# 3        False
# 4         True
# 5        False
#          ...
# 26096    False
# 26097     True
# 26098     True
# 26099    False
# 26100    False
# Name: merged_at, Length: 17183, dtype: bool

# %%
prs_nan_free[merged & closed].groupby("day").agg({"one_vec":"sum"}).plot(grid=True)
# Out:
# <AxesSubplot:xlabel='day'>

# %%
prs_nan_free["day_of_week"] = prs_nan_free.created_at.dt.dayofweek

# %%
prs_nan_free["merged_at"] = pd.to_datetime(prs_nan_free.merged_at, unit="s")

# %%
prs_nan_free["closed_at"] = pd.to_datetime(prs_nan_free.closed_at, unit="s")

# %%
prs_nan_free
# Out:
#                                                    title  \
# 1                  Add link to GOPATH doc and fixup typo
# 2                            Add alpha API documentation
# 3                      Added etcd folder into .gitignore
# 4               [WIP] Added project template json-schema
# 5                          Add examples for pod creation
# ...                                                  ...
# 26096                  Bug 1949050: fix images.sh script
# 26097  WIP: monitor: Move "crashlooping pods" test to...
# 26098  refactor TestMultipleImageChangeBuildTriggers,...
# 26099  bug 1951705: allow HighOverallControlPlaneCPU ...
# 26100  bug 1949306: add e2e test to block usage of re...
#
#                                                     body size      created_by  \
# 1                                                    NaN   XS        jwforres
# 2                            Merge of csrwng/oo-api-v3\n  XXL          csrwng
# 3                                                          XS         mfojtik
# 4                                                           L         mfojtik
# 5                                                    NaN    M        jwforres
# ...                                                  ...  ...             ...
# 26096  This is a followup to https://github.com/opens...    S         soltysh
# 26097  Crashlooping, long pulls, and other container ...    L  smarterclayton
# 26098  So reworking this test was motivated by 2 thin...  XXL     gabemontero
# 26099  adding the alert in https://github.com/openshi...   XS         deads2k
# 26100  Right now this is set to flake in CI and provi...  XXL         deads2k
#
#                created_at           closed_at              closed_by  \
# 1     2014-08-11 12:16:23 2014-08-11 12:18:22         smarterclayton
# 2     2014-08-12 09:16:32 2014-08-12 11:55:33                 danmcp
# 3     2014-08-12 09:39:38 2014-08-12 18:06:53         smarterclayton
# 4     2014-08-12 11:33:24 2014-08-15 07:30:30                mfojtik
# 5     2014-08-12 12:33:07 2014-08-12 18:07:07         smarterclayton
# ...                   ...                 ...                    ...
# 26096 2021-04-21 08:32:59 2021-04-22 05:35:21  openshift-merge-robot
# 26097 2021-04-21 20:08:52                 NaT                    NaN
# 26098 2021-04-21 20:32:12                 NaT            gabemontero
# 26099 2021-04-22 11:38:31 2021-04-22 17:44:30  openshift-merge-robot
# 26100 2021-04-22 15:13:49 2021-04-24 08:45:40  openshift-merge-robot
#
#                 merged_at  changed_files_number  \
# 1     2014-08-11 12:18:22                     1
# 2     2014-08-12 11:55:33                    54
# 3     2014-08-12 18:06:53                     1
# 4                     NaT                     1
# 5     2014-08-12 18:07:07                     7
# ...                   ...                   ...
# 26096 2021-04-22 05:35:21                     2
# 26097                 NaT                     5
# 26098                 NaT                   118
# 26099 2021-04-22 17:44:30                     1
# 26100 2021-04-24 08:45:40                   135
#
#                                                  commits  \
# 1             [3c15fd6dd7cee58393feb786fd7876b6f22fe9b5]
# 2             [24acb7993293e311e8c1f76f4b17791998c2f391]
# 3             [46c010676eb2655d256f29e2413f97aeeff17310]
# 4             [8af28a76da8bf8fd0293501bca49b423e652005e]
# 5             [cfbef75adee9cb5208d7e4c58ac8b1bf4dbdc1aa]
# ...                                                  ...
# 26096         [06830a927241a44ae24e9a4b5b2ac75f666d36bc]
# 26097         [95756458436b0e79a7ea779c6b0f6de2e4ee5a1f]
# 26098  [2d329e88159f7af1594054ce467cfdb3c320b612, e7e...
# 26099         [7bc10c83eea29010f3b735c41847d43a992f606c]
# 26100  [13b0e99d5f35d85998af9f07eb0c5b7d6fcc0dd0, 0c3...
#
#                                            changed_files  counts        day  \
# 1                                            [README.md]       1 2014-08-11
# 2      [api/README.md, api/build_flow.odg, api/doc/co...       2 2014-08-12
# 3                                           [.gitignore]       3 2014-08-12
# 4                          [api/doc/project.json_schema]       4 2014-08-12
# 5      [README.md, examples/hello-openshift/Dockerfil...       5 2014-08-12
# ...                                                  ...     ...        ...
# 26096  [test/extended/testdata/bindata.go, test/exten...   17179 2021-04-21
# 26097  [pkg/monitor/pod.go, pkg/synthetictests/event_...   17180 2021-04-21
# 26098  [go.mod, go.sum, test/extended/images/imagecha...   17181 2021-04-21
# 26099           [test/extended/prometheus/prometheus.go]   17182 2021-04-22
# 26100  [go.mod, go.sum, test/extended/apiserver/api_r...   17183 2021-04-22
#
#        one_vec  day_of_week
# 1            1            0
# 2            1            1
# 3            1            1
# 4            1            1
# 5            1            1
# ...        ...          ...
# 26096        1            2
# 26097        1            2
# 26098        1            2
# 26099        1            3
# 26100        1            3
#
# [17183 rows x 15 columns]

# %%
prs_nan_free["hour"] = prs_nan_free.created_at.dt.hour

# %%
prs_nan_free
# Out:
#                                                    title  \
# 1                  Add link to GOPATH doc and fixup typo
# 2                            Add alpha API documentation
# 3                      Added etcd folder into .gitignore
# 4               [WIP] Added project template json-schema
# 5                          Add examples for pod creation
# ...                                                  ...
# 26096                  Bug 1949050: fix images.sh script
# 26097  WIP: monitor: Move "crashlooping pods" test to...
# 26098  refactor TestMultipleImageChangeBuildTriggers,...
# 26099  bug 1951705: allow HighOverallControlPlaneCPU ...
# 26100  bug 1949306: add e2e test to block usage of re...
#
#                                                     body size      created_by  \
# 1                                                    NaN   XS        jwforres
# 2                            Merge of csrwng/oo-api-v3\n  XXL          csrwng
# 3                                                          XS         mfojtik
# 4                                                           L         mfojtik
# 5                                                    NaN    M        jwforres
# ...                                                  ...  ...             ...
# 26096  This is a followup to https://github.com/opens...    S         soltysh
# 26097  Crashlooping, long pulls, and other container ...    L  smarterclayton
# 26098  So reworking this test was motivated by 2 thin...  XXL     gabemontero
# 26099  adding the alert in https://github.com/openshi...   XS         deads2k
# 26100  Right now this is set to flake in CI and provi...  XXL         deads2k
#
#                created_at           closed_at              closed_by  \
# 1     2014-08-11 12:16:23 2014-08-11 12:18:22         smarterclayton
# 2     2014-08-12 09:16:32 2014-08-12 11:55:33                 danmcp
# 3     2014-08-12 09:39:38 2014-08-12 18:06:53         smarterclayton
# 4     2014-08-12 11:33:24 2014-08-15 07:30:30                mfojtik
# 5     2014-08-12 12:33:07 2014-08-12 18:07:07         smarterclayton
# ...                   ...                 ...                    ...
# 26096 2021-04-21 08:32:59 2021-04-22 05:35:21  openshift-merge-robot
# 26097 2021-04-21 20:08:52                 NaT                    NaN
# 26098 2021-04-21 20:32:12                 NaT            gabemontero
# 26099 2021-04-22 11:38:31 2021-04-22 17:44:30  openshift-merge-robot
# 26100 2021-04-22 15:13:49 2021-04-24 08:45:40  openshift-merge-robot
#
#                 merged_at  changed_files_number  \
# 1     2014-08-11 12:18:22                     1
# 2     2014-08-12 11:55:33                    54
# 3     2014-08-12 18:06:53                     1
# 4                     NaT                     1
# 5     2014-08-12 18:07:07                     7
# ...                   ...                   ...
# 26096 2021-04-22 05:35:21                     2
# 26097                 NaT                     5
# 26098                 NaT                   118
# 26099 2021-04-22 17:44:30                     1
# 26100 2021-04-24 08:45:40                   135
#
#                                                  commits  \
# 1             [3c15fd6dd7cee58393feb786fd7876b6f22fe9b5]
# 2             [24acb7993293e311e8c1f76f4b17791998c2f391]
# 3             [46c010676eb2655d256f29e2413f97aeeff17310]
# 4             [8af28a76da8bf8fd0293501bca49b423e652005e]
# 5             [cfbef75adee9cb5208d7e4c58ac8b1bf4dbdc1aa]
# ...                                                  ...
# 26096         [06830a927241a44ae24e9a4b5b2ac75f666d36bc]
# 26097         [95756458436b0e79a7ea779c6b0f6de2e4ee5a1f]
# 26098  [2d329e88159f7af1594054ce467cfdb3c320b612, e7e...
# 26099         [7bc10c83eea29010f3b735c41847d43a992f606c]
# 26100  [13b0e99d5f35d85998af9f07eb0c5b7d6fcc0dd0, 0c3...
#
#                                            changed_files  counts        day  \
# 1                                            [README.md]       1 2014-08-11
# 2      [api/README.md, api/build_flow.odg, api/doc/co...       2 2014-08-12
# 3                                           [.gitignore]       3 2014-08-12
# 4                          [api/doc/project.json_schema]       4 2014-08-12
# 5      [README.md, examples/hello-openshift/Dockerfil...       5 2014-08-12
# ...                                                  ...     ...        ...
# 26096  [test/extended/testdata/bindata.go, test/exten...   17179 2021-04-21
# 26097  [pkg/monitor/pod.go, pkg/synthetictests/event_...   17180 2021-04-21
# 26098  [go.mod, go.sum, test/extended/images/imagecha...   17181 2021-04-21
# 26099           [test/extended/prometheus/prometheus.go]   17182 2021-04-22
# 26100  [go.mod, go.sum, test/extended/apiserver/api_r...   17183 2021-04-22
#
#        one_vec  day_of_week  hour
# 1            1            0    12
# 2            1            1     9
# 3            1            1     9
# 4            1            1    11
# 5            1            1    12
# ...        ...          ...   ...
# 26096        1            2     8
# 26097        1            2    20
# 26098        1            2    20
# 26099        1            3    11
# 26100        1            3    15
#
# [17183 rows x 16 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [20, 10]

# %% [markdown]
# ## PRs count per hour

# %%
prs_nan_free.groupby("hour").agg({"one_vec":"sum"}).plot.bar()
# Out:
# <AxesSubplot:xlabel='hour'>

# %% [markdown]
# ## PRs per Day of week (starting from Monday as 0)

# %%
prs_nan_free.groupby("day_of_week").agg({"one_vec":"sum"}).plot.bar(grid=True)
# Out:
# <AxesSubplot:xlabel='day_of_week'>

# %% [markdown]
# ## PR count per sizes

# %%
prs_nan_free.groupby("size").agg({"one_vec":"sum"}).sort_values(by=["one_vec"]).plot.bar(grid=True)
# Out:
# <AxesSubplot:xlabel='size'>

# %% [markdown]
# ## Contributors' PR count

# %%
prs_nan_free.groupby("created_by").agg({"one_vec":"sum"}).sort_values(by="one_vec",ascending=False)[:50].plot.bar(grid=True)
# Out:
# <AxesSubplot:xlabel='created_by'>

# %% [markdown]
# ### what does that mean? - long tail, I have to make sure that the recommendation system does not only people on the left nor people on the right

# %%
prs_nan_free.groupby("created_by").agg({"one_vec":"sum"}).sort_values(by="one_vec",).reset_index().plot(y="one_vec", x="created_by", grid=True)
# Out:
# <AxesSubplot:xlabel='created_by'>

# %% [markdown]
# ## Cumulative sum of contributors' PR count

# %%
prs_nan_free.groupby("created_by").agg({"one_vec":"sum"}).sort_values(by="one_vec",ascending=True).reset_index().agg({"one_vec":"cumsum"}).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Time related kNN model recommender

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kn = KNeighborsClassifier(n_neighbors=20)

# %%
contributors_times = prs_nan_free.drop(prs_nan_free.columns.difference(["created_by", "day_of_week", "hour"]),axis=1)

# %%
contributors_times
# Out:
#            created_by  day_of_week  hour
# 1            jwforres            0    12
# 2              csrwng            1     9
# 3             mfojtik            1     9
# 4             mfojtik            1    11
# 5            jwforres            1    12
# ...               ...          ...   ...
# 26096         soltysh            2     8
# 26097  smarterclayton            2    20
# 26098     gabemontero            2    20
# 26099         deads2k            3    11
# 26100         deads2k            3    15
#
# [17183 rows x 3 columns]

# %%
y = contributors_times["created_by"]
X = contributors_times.drop("created_by", axis=1)

# %% [markdown]
# ### Encode contributors so that KNN from scikit learn can use them as numeric values

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
le.fit(y)
y_encoded = le.transform(y)

# %%
y_encoded
# Out:
# array([294, 119, 350, ..., 185, 135, 135])

# %% [markdown]
# ### Perform 3-fold Cross validation on the KNN model

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(kn, X, y_encoded, cv=3)
# Out:
# /home/xtuchyna/.local/share/virtualenvs/socrates-fiLER_zb/lib64/python3.8/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(("The least populated class in y has only %d"

# %%
scores
# Out:
# array([0.13041201, 0.12918994, 0.11803737])

# %% [markdown]
# ### What went wrong?
# We need to filter out people who have less than x contributions. The time constraint is also important, so we can consider only people who contributed to the project in last 6 months or so.

# %%
prs_nan_free.index.name = "pr_id"

# %%
prs_dates = prs_nan_free.reset_index().set_index("created_at")

# %%
print(prs_dates.shape, prs_nan_free.shape)
# Out:
# (17183, 16) (17183, 16)

# %%
last_6_months = prs_dates.last("6M")

# %%
last_6_months.shape
# Out:
# (408, 16)

# %%
contributors_6_month = last_6_months.groupby("created_by").agg({"one_vec":"sum"}).sort_values(by="one_vec")
more_than_2 = contributors_6_month["one_vec"] > 2
contributors_3_or_more = contributors_6_month[ more_than_2 ]
contributors_3_or_more
# Out:
#                             one_vec
# created_by
# jhadvig                           3
# candita                           3
# ehashman                          3
# sttts                             3
# bparees                           3
# gnufied                           3
# damemi                            4
# simonpasquier                     4
# omertuc                           5
# ardaguclu                         5
# ravisantoshgudimetla              5
# danwinship                        6
# dmage                             6
# sgreene570                        7
# jsafrane                          7
# marun                             8
# stbenjam                          9
# adambkaplan                       9
# tnozicka                          9
# openshift-bot                     9
# ingvagabund                      10
# stlaz                            11
# wking                            13
# vrutkovs                         13
# p0lyn0mial                       14
# gabemontero                      17
# frobware                         17
# deads2k                          23
# soltysh                          28
# openshift-cherrypick-robot       31
# smarterclayton                   69

# %% [markdown]
# ### Too small number of contributors for last 6 months with more than 2 PRs, why?
#
# Hypothesis: not everybody who reviews has to be best contributor. In fact, there can be good and experienced reviewers who do not contribute to the project at all.
# ### Therefore next important task is to: Make a reviewer dataframe

# %% [markdown]
# ## Reviewers data

# %% [markdown]
# Look at some reviews collected example data

# %%
prs_cleared["reviews"][19886]
# Out:
# {'124504626': {'author': 'pravisankar',
#   'words_count': 1,
#   'submitted_at': 1527693223,
#   'state': 'APPROVED'},
#  '124506061': {'author': 'knobunc',
#   'words_count': 1,
#   'submitted_at': 1527693447,
#   'state': 'APPROVED'}}

# %%
def get_reviews(row):
    data = []
    reviews = row.reviews.values()
    for rev in reviews:
        data.append([row.name, row.created_by, rev["author"], rev["words_count"], rev["submitted_at"], rev["state"]])
    return data

# %%
not_empty = prs_cleared["reviews"] != {}

# %%
reviews = prs_cleared[not_empty].apply(lambda x:get_reviews(x),axis=1)
reviews
# Out:
# 26096    [[26096, soltysh, adambkaplan, 1, 1619032331, ...
# 26093    [[26093, ihcsim, deads2k, 1, 1618933922, COMME...
# 26092    [[26092, deads2k, tkashem, 1, 1618940554, COMM...
# 26091    [[26091, soltysh, adambkaplan, 5, 1618920327, ...
# 26088    [[26088, jkhelil, soltysh, 1, 1618923935, COMM...
#                                ...
# 8938     [[8938, legionus, vbatts, 1, 1489689675, COMME...
# 8258     [[8258, ghost, smarterclayton, 1, 1479491396, ...
# 8094     [[8094, nak3, juanvallejo, 1, 1485979362, COMM...
# 7956     [[7956, stefwalter, legionus, 5, 1486733389, C...
# 7446     [[7446, umairmufti, mfojtik, 1, 1484895398, CO...
# Length: 4440, dtype: object

# %%
reviews_list = reviews.explode().tolist()
reviews_list
# Out:
# [[26096, 'soltysh', 'adambkaplan', 1, 1619032331, 'APPROVED'],
#  [26093, 'ihcsim', 'deads2k', 1, 1618933922, 'COMMENTED'],
#  [26093, 'ihcsim', 'ihcsim', 1, 1618935064, 'COMMENTED'],
#  [26092, 'deads2k', 'tkashem', 1, 1618940554, 'COMMENTED'],
#  [26092, 'deads2k', 'tkashem', 1, 1618940911, 'COMMENTED'],
#  [26092, 'deads2k', 'deads2k', 1, 1618941043, 'COMMENTED'],
#  [26092, 'deads2k', 'wking', 1, 1618945490, 'COMMENTED'],
#  [26091, 'soltysh', 'adambkaplan', 5, 1618920327, 'CHANGES_REQUESTED'],
#  [26091, 'soltysh', 'soltysh', 1, 1618923128, 'COMMENTED'],
#  [26091, 'soltysh', 'adambkaplan', 1, 1619032291, 'APPROVED'],
#  [26088, 'jkhelil', 'soltysh', 1, 1618923935, 'COMMENTED'],
#  [26088, 'jkhelil', 'LorbusChris', 1, 1618926724, 'COMMENTED'],
#  [26088, 'jkhelil', 'jkhelil', 1, 1618928714, 'COMMENTED'],
#  [26088, 'jkhelil', 'soltysh', 7, 1618929986, 'APPROVED'],
#  [26087, 'wking', 'JoelSpeed', 1, 1618816152, 'COMMENTED'],
#  [26086, 'frobware', 'sgreene570', 1, 1618577248, 'COMMENTED'],
#  [26086, 'frobware', 'frobware', 1, 1618578362, 'COMMENTED'],
#  [26086, 'frobware', 'frobware', 1, 1618578389, 'COMMENTED'],
#  [26083, 'frobware', 'candita', 1, 1618512834, 'COMMENTED'],
#  [26083, 'frobware', 'frobware', 1, 1618551122, 'COMMENTED'],
#  [26082, 'adambkaplan', 'adambkaplan', 7, 1618489267, 'COMMENTED'],
#  [26082, 'adambkaplan', 'soltysh', 1, 1618492114, 'APPROVED'],
#  [26082, 'adambkaplan', 'xiuwang', 1, 1618547129, 'COMMENTED'],
#  [26071, 'astoycos', 'squeed', 1, 1618400749, 'COMMENTED'],
#  [26071, 'astoycos', 'squeed', 1, 1618400940, 'COMMENTED'],
#  [26071, 'astoycos', 'squeed', 1, 1618400982, 'COMMENTED'],
#  [26071, 'astoycos', 'squeed', 1, 1618401083, 'COMMENTED'],
#  [26071, 'astoycos', 'danwinship', 1, 1618402135, 'COMMENTED'],
#  [26071, 'astoycos', 'astoycos', 1, 1618402685, 'COMMENTED'],
#  [26069, 'frobware', 'knobunc', 1, 1618582433, 'APPROVED'],
#  [26068, 'frobware', 'candita', 1, 1618317817, 'COMMENTED'],
#  [26068, 'frobware', 'frobware', 1, 1618318248, 'COMMENTED'],
#  [26068, 'frobware', 'sgreene570', 1, 1618318344, 'COMMENTED'],
#  [26067,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1618342339,
#   'COMMENTED'],
#  [26067, 'ravisantoshgudimetla', 'dhellmann', 1, 1618847092, 'COMMENTED'],
#  [26067,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1618847762,
#   'COMMENTED'],
#  [26067, 'ravisantoshgudimetla', 'omertuc', 1, 1618855800, 'COMMENTED'],
#  [26067, 'ravisantoshgudimetla', 'omertuc', 1, 1618856871, 'COMMENTED'],
#  [26067,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1619014245,
#   'COMMENTED'],
#  [26067,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1619014366,
#   'COMMENTED'],
#  [26063, 'bparees', 'smarterclayton', 1, 1618230681, 'COMMENTED'],
#  [26063, 'bparees', 'smarterclayton', 1, 1618230687, 'COMMENTED'],
#  [26063, 'bparees', 'bparees', 1, 1618231555, 'COMMENTED'],
#  [26063, 'bparees', 'smarterclayton', 1, 1618325995, 'COMMENTED'],
#  [26063, 'bparees', 'bparees', 1, 1618327843, 'COMMENTED'],
#  [26063, 'bparees', 'bparees', 1, 1618328653, 'COMMENTED'],
#  [26061, 'vrutkovs', 'smarterclayton', 1, 1618235031, 'COMMENTED'],
#  [26061, 'vrutkovs', 'vrutkovs', 1, 1618235433, 'COMMENTED'],
#  [26061, 'vrutkovs', 'smarterclayton', 1, 1618235961, 'COMMENTED'],
#  [26061, 'vrutkovs', 'smarterclayton', 1, 1618235985, 'COMMENTED'],
#  [26061, 'vrutkovs', 'vrutkovs', 1, 1618238858, 'COMMENTED'],
#  [26059, 'danwinship', 'knobunc', 1, 1618498954, 'COMMENTED'],
#  [26056, 'smarterclayton', 'soltysh', 1, 1617868152, 'APPROVED'],
#  [26054, 'soltysh', 'smarterclayton', 1, 1618320292, 'COMMENTED'],
#  [26054, 'soltysh', 'soltysh', 1, 1618320888, 'COMMENTED'],
#  [26053, 'stlaz', 'dmage', 1, 1617786679, 'COMMENTED'],
#  [26053, 'stlaz', 'stlaz', 1, 1617788272, 'COMMENTED'],
#  [26053, 'stlaz', 'soltysh', 1, 1617802211, 'APPROVED'],
#  [26052, 'stlaz', 'adambkaplan', 1, 1617880728, 'APPROVED'],
#  [26045, 'ingvagabund', 'soltysh', 1, 1619080987, 'APPROVED'],
#  [26044, 'frobware', 'candita', 1, 1617797262, 'COMMENTED'],
#  [26044, 'frobware', 'candita', 1, 1617797480, 'COMMENTED'],
#  [26044, 'frobware', 'candita', 1, 1617797600, 'COMMENTED'],
#  [26044, 'frobware', 'candita', 1, 1617797830, 'COMMENTED'],
#  [26044, 'frobware', 'candita', 1, 1617798120, 'COMMENTED'],
#  [26044, 'frobware', 'sgreene570', 1, 1617800016, 'COMMENTED'],
#  [26044, 'frobware', 'sgreene570', 1, 1617800076, 'COMMENTED'],
#  [26044, 'frobware', 'sgreene570', 1, 1617800570, 'COMMENTED'],
#  [26044, 'frobware', 'frobware', 1, 1617802566, 'COMMENTED'],
#  [26044, 'frobware', 'frobware', 1, 1617802629, 'COMMENTED'],
#  [26044, 'frobware', 'frobware', 1, 1617803942, 'COMMENTED'],
#  [26044, 'frobware', 'candita', 1, 1617821019, 'COMMENTED'],
#  [26044, 'frobware', 'candita', 1, 1617821219, 'COMMENTED'],
#  [26044, 'frobware', 'frobware', 1, 1618236994, 'COMMENTED'],
#  [26043, 'andfasano', 'ardaguclu', 1, 1617339387, 'COMMENTED'],
#  [26043, 'andfasano', 'andfasano', 1, 1617345205, 'COMMENTED'],
#  [26043, 'andfasano', 'andfasano', 1, 1617345353, 'COMMENTED'],
#  [26034, 'deads2k', 'soltysh', 1, 1617260014, 'APPROVED'],
#  [26034, 'deads2k', 'wking', 1, 1617287318, 'COMMENTED'],
#  [26034, 'deads2k', 'deads2k', 1, 1617291959, 'COMMENTED'],
#  [26027, 'vrutkovs', 'smarterclayton', 1, 1617213191, 'COMMENTED'],
#  [26022, 'smarterclayton', 'cgwalters', 15, 1616787660, 'APPROVED'],
#  [26021, 'smarterclayton', 'cgwalters', 25, 1616787878, 'APPROVED'],
#  [26019, 'stbenjam', 'smarterclayton', 1, 1616695535, 'COMMENTED'],
#  [26019, 'stbenjam', 'stbenjam', 1, 1616697094, 'COMMENTED'],
#  [26019, 'stbenjam', 'stbenjam', 1, 1616697643, 'COMMENTED'],
#  [26019, 'stbenjam', 'smarterclayton', 1, 1616712155, 'COMMENTED'],
#  [26019, 'stbenjam', 'stbenjam', 1, 1616716087, 'COMMENTED'],
#  [26019, 'stbenjam', 'smarterclayton', 1, 1617041830, 'COMMENTED'],
#  [26019, 'stbenjam', 'stbenjam', 1, 1617098546, 'COMMENTED'],
#  [26017, 'vrutkovs', 'adambkaplan', 1, 1616698133, 'APPROVED'],
#  [26016, 'simonpasquier', 'paulfantom', 1, 1616681790, 'APPROVED'],
#  [26016, 'simonpasquier', 'smarterclayton', 1, 1616711542, 'COMMENTED'],
#  [26016, 'simonpasquier', 'simonpasquier', 1, 1616742200, 'COMMENTED'],
#  [26015, 'adambkaplan', 'gabemontero', 1, 1617809017, 'APPROVED'],
#  [26015, 'adambkaplan', 'rolfedh', 1, 1618233173, 'APPROVED'],
#  [26015, 'adambkaplan', 'otaviof', 1, 1618312999, 'APPROVED'],
#  [26013, 'openshift-bot', 'soltysh', 1, 1616519596, 'APPROVED'],
#  [26011, 'openshift-bot', 'soltysh', 1, 1616519608, 'APPROVED'],
#  [26010, 'p0lyn0mial', 'p0lyn0mial', 1, 1616504369, 'COMMENTED'],
#  [26010, 'p0lyn0mial', 'p0lyn0mial', 1, 1616504392, 'COMMENTED'],
#  [26010, 'p0lyn0mial', 'smarterclayton', 1, 1616504662, 'COMMENTED'],
#  [26010, 'p0lyn0mial', 'smarterclayton', 1, 1616504799, 'COMMENTED'],
#  [26010, 'p0lyn0mial', 'smarterclayton', 1, 1616504903, 'COMMENTED'],
#  [26010, 'p0lyn0mial', 'smarterclayton', 1, 1616505333, 'COMMENTED'],
#  [26010, 'p0lyn0mial', 'smarterclayton', 1, 1616507916, 'COMMENTED'],
#  [26009, 'stlaz', 'sttts', 1, 1617095560, 'COMMENTED'],
#  [26009, 'stlaz', 'sttts', 1, 1617095606, 'COMMENTED'],
#  [26009, 'stlaz', 'stlaz', 1, 1617095689, 'COMMENTED'],
#  [26009, 'stlaz', 'sttts', 1, 1617095694, 'COMMENTED'],
#  [26009, 'stlaz', 'stlaz', 1, 1617095782, 'COMMENTED'],
#  [26009, 'stlaz', 'sttts', 1, 1617096765, 'COMMENTED'],
#  [26009, 'stlaz', 'sttts', 1, 1617096781, 'COMMENTED'],
#  [26009, 'stlaz', 'sttts', 1, 1617096788, 'COMMENTED'],
#  [26008, 'stbenjam', 'danwinship', 1, 1616498948, 'CHANGES_REQUESTED'],
#  [26008, 'stbenjam', 'stbenjam', 1, 1616504557, 'COMMENTED'],
#  [26006, 'deads2k', 'mfojtik', 1, 1617016309, 'COMMENTED'],
#  [26005, 'deads2k', 'smarterclayton', 1, 1616434609, 'COMMENTED'],
#  [26005, 'deads2k', 'deads2k', 1, 1617033020, 'COMMENTED'],
#  [26004, 'deads2k', 'mfojtik', 1, 1616673637, 'COMMENTED'],
#  [26004, 'deads2k', 'mfojtik', 1, 1616673669, 'COMMENTED'],
#  [26004, 'deads2k', 'mfojtik', 1, 1616673710, 'COMMENTED'],
#  [26004, 'deads2k', 'mfojtik', 1, 1616673786, 'COMMENTED'],
#  [26004, 'deads2k', 'mfojtik', 1, 1616674334, 'COMMENTED'],
#  [26004, 'deads2k', 'deads2k', 1, 1616674388, 'COMMENTED'],
#  [26004, 'deads2k', 'deads2k', 1, 1616674544, 'COMMENTED'],
#  [26004, 'deads2k', 'deads2k', 1, 1616674613, 'COMMENTED'],
#  [26004, 'deads2k', 'deads2k', 1, 1616674630, 'COMMENTED'],
#  [25999, 'frobware', 'candita', 1, 1616504868, 'COMMENTED'],
#  [25999, 'frobware', 'candita', 1, 1616522092, 'COMMENTED'],
#  [25993, 'cgwalters', 'ashcrow', 1, 1616770017, 'APPROVED'],
#  [25988, 'smarterclayton', 'soltysh', 1, 1616162217, 'APPROVED'],
#  [25985, 'gabemontero', 'adambkaplan', 1, 1616171840, 'APPROVED'],
#  [25983, 'ravisantoshgudimetla', 'smarterclayton', 1, 1616122948, 'COMMENTED'],
#  [25983, 'ravisantoshgudimetla', 'soltysh', 1, 1616150263, 'COMMENTED'],
#  [25983,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1616157747,
#   'COMMENTED'],
#  [25978, 'smarterclayton', 'ehashman', 1, 1616012838, 'COMMENTED'],
#  [25978, 'smarterclayton', 'smarterclayton', 1, 1616014705, 'COMMENTED'],
#  [25971, 'smarterclayton', 'ravisantoshgudimetla', 8, 1615984907, 'APPROVED'],
#  [25968, 'wking', 'smarterclayton', 1, 1615929213, 'COMMENTED'],
#  [25968, 'wking', 'wking', 1, 1615937360, 'COMMENTED'],
#  [25966,
#   'openshift-cherrypick-robot',
#   'adambkaplan',
#   1,
#   1615902368,
#   'APPROVED'],
#  [25966, 'openshift-cherrypick-robot', 'xiuwang', 1, 1615940384, 'COMMENTED'],
#  [25966, 'openshift-cherrypick-robot', 'xiuwang', 1, 1615940571, 'COMMENTED'],
#  [25966, 'openshift-cherrypick-robot', 'xiuwang', 1, 1615940634, 'COMMENTED'],
#  [25966, 'openshift-cherrypick-robot', 'xiuwang', 1, 1615940650, 'COMMENTED'],
#  [25966, 'openshift-cherrypick-robot', 'xiuwang', 1, 1615940681, 'COMMENTED'],
#  [25966,
#   'openshift-cherrypick-robot',
#   'adambkaplan',
#   1,
#   1615990711,
#   'COMMENTED'],
#  [25965, 'stlaz', 'sttts', 1, 1615893848, 'COMMENTED'],
#  [25965, 'stlaz', 'EmilyM1', 1, 1616002332, 'APPROVED'],
#  [25959, 'smarterclayton', 'wking', 1, 1615938544, 'COMMENTED'],
#  [25957, 'smarterclayton', 'wking', 1, 1615475901, 'APPROVED'],
#  [25954, 'sgreene570', 'candita', 1, 1616443368, 'COMMENTED'],
#  [25954, 'sgreene570', 'sgreene570', 1, 1616443710, 'COMMENTED'],
#  [25954, 'sgreene570', 'candita', 1, 1616443906, 'COMMENTED'],
#  [25954, 'sgreene570', 'candita', 1, 1616446496, 'COMMENTED'],
#  [25954, 'sgreene570', 'sgreene570', 1, 1616503837, 'COMMENTED'],
#  [25954, 'sgreene570', 'sgreene570', 1, 1616504159, 'COMMENTED'],
#  [25954, 'sgreene570', 'candita', 1, 1616592599, 'COMMENTED'],
#  [25954, 'sgreene570', 'candita', 1, 1616593033, 'COMMENTED'],
#  [25954, 'sgreene570', 'sgreene570', 1, 1616595300, 'COMMENTED'],
#  [25954, 'sgreene570', 'candita', 1, 1616769542, 'COMMENTED'],
#  [25954, 'sgreene570', 'candita', 1, 1616769794, 'COMMENTED'],
#  [25954, 'sgreene570', 'sgreene570', 1, 1616769937, 'COMMENTED'],
#  [25954, 'sgreene570', 'Miciah', 1, 1616791682, 'COMMENTED'],
#  [25954, 'sgreene570', 'sgreene570', 1, 1617017330, 'COMMENTED'],
#  [25954, 'sgreene570', 'knobunc', 2, 1617107293, 'APPROVED'],
#  [25954, 'sgreene570', 'sgreene570', 1, 1617107709, 'COMMENTED'],
#  [25954, 'sgreene570', 'Miciah', 1, 1617116022, 'COMMENTED'],
#  [25951,
#   'openshift-cherrypick-robot',
#   'adambkaplan',
#   1,
#   1615299625,
#   'APPROVED'],
#  [25950, 'ardaguclu', 'stbenjam', 1, 1615460983, 'COMMENTED'],
#  [25950, 'ardaguclu', 'stbenjam', 1, 1615461126, 'COMMENTED'],
#  [25950, 'ardaguclu', 'ardaguclu', 1, 1615461313, 'COMMENTED'],
#  [25950, 'ardaguclu', 'ardaguclu', 1, 1615461418, 'COMMENTED'],
#  [25950, 'ardaguclu', 'ardaguclu', 1, 1615463691, 'COMMENTED'],
#  [25950, 'ardaguclu', 'stbenjam', 1, 1617704863, 'COMMENTED'],
#  [25950, 'ardaguclu', 'ardaguclu', 1, 1617705367, 'COMMENTED'],
#  [25950, 'ardaguclu', 'stbenjam', 1, 1617705697, 'COMMENTED'],
#  [25949, 'vrutkovs', 'adambkaplan', 1, 1615819287, 'APPROVED'],
#  [25946, 'bparees', 'smarterclayton', 1, 1617044600, 'COMMENTED'],
#  [25946, 'bparees', 'bparees', 1, 1617045132, 'COMMENTED'],
#  [25946, 'bparees', 'bparees', 1, 1617045189, 'COMMENTED'],
#  [25946, 'bparees', 'bparees', 1, 1617045523, 'COMMENTED'],
#  [25945, 'ravisantoshgudimetla', 'smarterclayton', 1, 1615299065, 'COMMENTED'],
#  [25945,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1615300060,
#   'COMMENTED'],
#  [25945, 'ravisantoshgudimetla', 'smarterclayton', 1, 1615303500, 'COMMENTED'],
#  [25945,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1615304037,
#   'COMMENTED'],
#  [25945,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1615390102,
#   'COMMENTED'],
#  [25945, 'ravisantoshgudimetla', 'smarterclayton', 1, 1615486592, 'COMMENTED'],
#  [25945, 'ravisantoshgudimetla', 'smarterclayton', 1, 1615486817, 'COMMENTED'],
#  [25945, 'ravisantoshgudimetla', 'smarterclayton', 1, 1615486845, 'COMMENTED'],
#  [25945,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1615842708,
#   'COMMENTED'],
#  [25945, 'ravisantoshgudimetla', 'smarterclayton', 1, 1615922124, 'COMMENTED'],
#  [25945, 'ravisantoshgudimetla', 'smarterclayton', 1, 1615922176, 'COMMENTED'],
#  [25945,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1615922379,
#   'COMMENTED'],
#  [25945,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1615922442,
#   'COMMENTED'],
#  [25945, 'ravisantoshgudimetla', 'smarterclayton', 1, 1615922484, 'COMMENTED'],
#  [25945, 'ravisantoshgudimetla', 'smarterclayton', 1, 1615922508, 'COMMENTED'],
#  [25945, 'ravisantoshgudimetla', 'smarterclayton', 1, 1615922532, 'COMMENTED'],
#  [25945, 'ravisantoshgudimetla', 'smarterclayton', 1, 1615922558, 'COMMENTED'],
#  [25945, 'ravisantoshgudimetla', 'smarterclayton', 1, 1615922985, 'COMMENTED'],
#  [25941, 'vrutkovs', 'bparees', 1, 1616422602, 'COMMENTED'],
#  [25941, 'vrutkovs', 'smarterclayton', 1, 1616423219, 'COMMENTED'],
#  [25941, 'vrutkovs', 'vrutkovs', 1, 1616423884, 'COMMENTED'],
#  [25940, 'ardaguclu', 'deads2k', 1, 1615213314, 'COMMENTED'],
#  [25940, 'ardaguclu', 'deads2k', 1, 1615214475, 'COMMENTED'],
#  [25939, 'smarterclayton', 'wking', 3, 1614910599, 'APPROVED'],
#  [25936, 'omertuc', 'smarterclayton', 1, 1615211100, 'COMMENTED'],
#  [25936, 'omertuc', 'omertuc', 1, 1615213931, 'COMMENTED'],
#  [25936, 'omertuc', 'smarterclayton', 1, 1615234344, 'COMMENTED'],
#  [25936, 'omertuc', 'smarterclayton', 1, 1615234396, 'COMMENTED'],
#  [25936, 'omertuc', 'omertuc', 1, 1615237316, 'COMMENTED'],
#  [25936, 'omertuc', 'omertuc', 1, 1615242445, 'COMMENTED'],
#  [25931, 'ravisantoshgudimetla', 'aravindhp', 1, 1619199439, 'COMMENTED'],
#  [25931,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1619200076,
#   'COMMENTED'],
#  [25931, 'ravisantoshgudimetla', 'aravindhp', 1, 1619200263, 'COMMENTED'],
#  [25930, 'JoelSpeed', 'elmiko', 7, 1615210080, 'APPROVED'],
#  [25930, 'JoelSpeed', 'alexander-demichev', 1, 1615210309, 'APPROVED'],
#  [25929, 'jhadvig', 'romfreiman', 1, 1614589121, 'COMMENTED'],
#  [25929, 'jhadvig', 'jhadvig', 1, 1614589299, 'COMMENTED'],
#  [25928, 'smarterclayton', 'wking', 1, 1614284895, 'COMMENTED'],
#  [25928, 'smarterclayton', 'wking', 1, 1614286017, 'COMMENTED'],
#  [25928, 'smarterclayton', 'michaelgugino', 1, 1614286431, 'COMMENTED'],
#  [25928, 'smarterclayton', 'smarterclayton', 1, 1614288985, 'COMMENTED'],
#  [25928, 'smarterclayton', 'smarterclayton', 1, 1614289004, 'COMMENTED'],
#  [25928, 'smarterclayton', 'smarterclayton', 1, 1614289092, 'COMMENTED'],
#  [25928, 'smarterclayton', 'michaelgugino', 1, 1614621403, 'COMMENTED'],
#  [25928, 'smarterclayton', 'smarterclayton', 1, 1614779227, 'COMMENTED'],
#  [25928, 'smarterclayton', 'wking', 1, 1614796855, 'COMMENTED'],
#  [25928, 'smarterclayton', 'wking', 1, 1614796954, 'COMMENTED'],
#  [25928, 'smarterclayton', 'michaelgugino', 1, 1614799154, 'COMMENTED'],
#  [25928, 'smarterclayton', 'wking', 1, 1614916994, 'COMMENTED'],
#  [25928, 'smarterclayton', 'wking', 1, 1614985140, 'COMMENTED'],
#  [25928, 'smarterclayton', 'wking', 1, 1615227047, 'COMMENTED'],
#  [25928, 'smarterclayton', 'wking', 1, 1615227558, 'COMMENTED'],
#  [25928, 'smarterclayton', 'wking', 1, 1615319018, 'COMMENTED'],
#  [25928, 'smarterclayton', 'wking', 1, 1615319466, 'COMMENTED'],
#  [25928, 'smarterclayton', 'smarterclayton', 1, 1615425853, 'COMMENTED'],
#  [25927, 'ravisantoshgudimetla', 'wking', 1, 1614282295, 'COMMENTED'],
#  [25927, 'ravisantoshgudimetla', 'wking', 1, 1614282337, 'COMMENTED'],
#  [25927,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1614282551,
#   'COMMENTED'],
#  [25927,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1614282645,
#   'COMMENTED'],
#  [25927, 'ravisantoshgudimetla', 'mrunalp', 1, 1614283402, 'COMMENTED'],
#  [25927, 'ravisantoshgudimetla', 'mrunalp', 1, 1614631726, 'COMMENTED'],
#  [25927, 'ravisantoshgudimetla', 'mrunalp', 1, 1614631859, 'COMMENTED'],
#  [25927,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1614633033,
#   'COMMENTED'],
#  [25927, 'ravisantoshgudimetla', 'mrunalp', 1, 1614635410, 'COMMENTED'],
#  [25927,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1614637176,
#   'COMMENTED'],
#  [25927, 'ravisantoshgudimetla', 'smarterclayton', 1, 1614703597, 'COMMENTED'],
#  [25927, 'ravisantoshgudimetla', 'smarterclayton', 1, 1614703664, 'COMMENTED'],
#  [25927, 'ravisantoshgudimetla', 'smarterclayton', 1, 1614703706, 'COMMENTED'],
#  [25927,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1614705135,
#   'COMMENTED'],
#  [25927,
#   'ravisantoshgudimetla',
#   'ravisantoshgudimetla',
#   1,
#   1614705527,
#   'COMMENTED'],
#  [25923, 'smarterclayton', 'wking', 1, 1614190400, 'APPROVED'],
#  [25923, 'smarterclayton', 'ravisantoshgudimetla', 1, 1614190466, 'APPROVED'],
#  [25922, 'smarterclayton', 'wking', 14, 1614116017, 'APPROVED'],
#  [25922, 'smarterclayton', 'wking', 1, 1614124512, 'COMMENTED'],
#  [25921, 'smarterclayton', 'wking', 1, 1614113839, 'COMMENTED'],
#  [25921, 'smarterclayton', 'smarterclayton', 1, 1614122716, 'COMMENTED'],
#  [25918, 'deads2k', 'wking', 1, 1614108897, 'COMMENTED'],
#  [25918, 'deads2k', 'deads2k', 1, 1614109750, 'COMMENTED'],
#  [25918, 'deads2k', 'smarterclayton', 1, 1614268201, 'COMMENTED'],
#  [25918, 'deads2k', 'deads2k', 1, 1614717777, 'COMMENTED'],
#  [25918, 'deads2k', 'smarterclayton', 1, 1614878325, 'COMMENTED'],
#  [25918, 'deads2k', 'smarterclayton', 1, 1614878349, 'COMMENTED'],
#  [25918, 'deads2k', 'deads2k', 1, 1614878648, 'COMMENTED'],
#  [25918, 'deads2k', 'mfojtik', 1, 1615207147, 'COMMENTED'],
#  [25918, 'deads2k', 'mfojtik', 1, 1615207205, 'COMMENTED'],
#  [25915, 'damemi', 'damemi', 1, 1614786848, 'COMMENTED'],
#  [25915, 'damemi', 'soltysh', 2, 1616755129, 'APPROVED'],
#  [25910, 'openshift-cherrypick-robot', 'soltysh', 2, 1613988688, 'APPROVED'],
#  [25908, 'openshift-cherrypick-robot', 'soltysh', 1, 1614586012, 'APPROVED'],
#  [25905, 'vrutkovs', 'smarterclayton', 1, 1614010623, 'COMMENTED'],
#  [25905, 'vrutkovs', 'vrutkovs', 1, 1614010705, 'COMMENTED'],
#  [25905, 'vrutkovs', 'vrutkovs', 1, 1614075689, 'COMMENTED'],
#  [25905, 'vrutkovs', 'smarterclayton', 1, 1614125217, 'COMMENTED'],
#  [25904, 'smarterclayton', 'wking', 1, 1614020128, 'COMMENTED'],
#  [25904, 'smarterclayton', 'wking', 1, 1614020217, 'COMMENTED'],
#  [25904, 'smarterclayton', 'wking', 1, 1614020264, 'COMMENTED'],
#  [25904, 'smarterclayton', 'wking', 1, 1614020357, 'COMMENTED'],
#  [25904, 'smarterclayton', 'smarterclayton', 1, 1614020683, 'COMMENTED'],
#  [25904, 'smarterclayton', 'jottofar', 1, 1614021096, 'COMMENTED'],
#  [25904, 'smarterclayton', 'michaelgugino', 1, 1614021277, 'COMMENTED'],
#  [25904, 'smarterclayton', 'jottofar', 1, 1614021426, 'COMMENTED'],
#  [25904, 'smarterclayton', 'wking', 1, 1614021594, 'COMMENTED'],
#  [25904, 'smarterclayton', 'smarterclayton', 1, 1614027889, 'COMMENTED'],
#  [25904, 'smarterclayton', 'smarterclayton', 1, 1614027904, 'COMMENTED'],
#  [25904, 'smarterclayton', 'wking', 1, 1614028738, 'COMMENTED'],
#  [25904, 'smarterclayton', 'wking', 1, 1614029093, 'COMMENTED'],
#  [25904, 'smarterclayton', 'smarterclayton', 1, 1614100850, 'COMMENTED'],
#  [25899, 'Fedosin', 'mandre', 1, 1613723009, 'COMMENTED'],
#  [25897, 'frobware', 'sgreene570', 1, 1615323521, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1615364994, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1615365048, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1615365318, 'COMMENTED'],
#  [25897, 'frobware', 'sgreene570', 1, 1616439062, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1616489807, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1616693822, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1616694448, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1616695452, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1616695772, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1616996249, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1616996257, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617711280, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617711409, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617712187, 'COMMENTED'],
#  [25897, 'frobware', 'sgreene570', 1, 1617712308, 'COMMENTED'],
#  [25897, 'frobware', 'sgreene570', 1, 1617713332, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617713435, 'COMMENTED'],
#  [25897, 'frobware', 'sgreene570', 1, 1617713476, 'COMMENTED'],
#  [25897, 'frobware', 'sgreene570', 1, 1617713654, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617713942, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617714346, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617714438, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617714442, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617714483, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617714540, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617714646, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617714711, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617714752, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617715693, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617717820, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617718112, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617722153, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617727259, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617728133, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617728525, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617728558, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617728573, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617730846, 'COMMENTED'],
#  [25897, 'frobware', 'candita', 1, 1617731679, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617784184, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617784218, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617784254, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617784424, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617786213, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617786343, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617790673, 'COMMENTED'],
#  [25897, 'frobware', 'sgreene570', 1, 1617800011, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617801200, 'COMMENTED'],
#  [25897, 'frobware', 'sgreene570', 1, 1617801270, 'COMMENTED'],
#  [25897, 'frobware', 'frobware', 1, 1617803695, 'COMMENTED'],
#  [25895, 'candita', 'Miciah', 1, 1613399306, 'COMMENTED'],
#  [25895, 'candita', 'candita', 1, 1613400313, 'COMMENTED'],
#  [25895, 'candita', 'candita', 1, 1613504034, 'COMMENTED'],
#  [25895, 'candita', 'Miciah', 28, 1613767936, 'COMMENTED'],
#  [25893, 'openshift-cherrypick-robot', 'candita', 1, 1617032815, 'COMMENTED'],
#  [25893, 'openshift-cherrypick-robot', 'frobware', 1, 1617709065, 'COMMENTED'],
#  [25893, 'openshift-cherrypick-robot', 'frobware', 1, 1617710137, 'COMMENTED'],
#  [25885, 'omertuc', 'simonpasquier', 1, 1613038104, 'COMMENTED'],
#  [25885, 'omertuc', 'simonpasquier', 3, 1617081575, 'COMMENTED'],
#  [25884,
#   'openshift-cherrypick-robot',
#   'adambkaplan',
#   1,
#   1615920373,
#   'APPROVED'],
#  [25880, 'mtrmac', 'mtrmac', 1, 1612978330, 'COMMENTED'],
#  [25880, 'mtrmac', 'soltysh', 1, 1613040395, 'COMMENTED'],
#  [25880, 'mtrmac', 'dmage', 1, 1613041760, 'COMMENTED'],
#  [25880, 'mtrmac', 'mtrmac', 1, 1613045692, 'COMMENTED'],
#  [25880, 'mtrmac', 'mtrmac', 1, 1613078487, 'COMMENTED'],
#  [25880, 'mtrmac', 'mtrmac', 1, 1613086134, 'COMMENTED'],
#  [25880, 'mtrmac', 'soltysh', 2, 1614682705, 'APPROVED'],
#  [25880, 'mtrmac', 'soltysh', 1, 1615825126, 'APPROVED'],
#  [25877, 'gabemontero', 'adambkaplan', 1, 1612966207, 'APPROVED'],
#  [25876, 'jsafrane', 'soltysh', 1, 1613047378, 'APPROVED'],
#  [25875, 'rphillips', 'saschagrunert', 1, 1616416021, 'APPROVED'],
#  [25874, 'frobware', 'sgreene570', 1, 1612877912, 'COMMENTED'],
#  [25874, 'frobware', 'frobware', 1, 1612879678, 'COMMENTED'],
#  [25874, 'frobware', 'frobware', 1, 1612880950, 'COMMENTED'],
#  [25874, 'frobware', 'knobunc', 3, 1613057908, 'APPROVED'],
#  [25873, 'openshift-bot', 'soltysh', 1, 1612872053, 'APPROVED'],
#  [25872, 'openshift-bot', 'soltysh', 1, 1612871934, 'APPROVED'],
#  [25863, 'soltysh', 'adambkaplan', 1, 1612807545, 'APPROVED'],
#  [25862, 'jsafrane', 'soltysh', 4, 1612524204, 'APPROVED'],
#  [25858, 'frobware', 'knobunc', 1, 1612450220, 'APPROVED'],
#  [25855, 'openshift-cherrypick-robot', 'soltysh', 1, 1612442658, 'APPROVED'],
#  [25853, 'andfasano', 'deads2k', 1, 1614692045, 'COMMENTED'],
#  [25853, 'andfasano', 'andfasano', 1, 1614694008, 'COMMENTED'],
#  [25853, 'andfasano', 'deads2k', 1, 1615213398, 'COMMENTED'],
#  [25853, 'andfasano', 'andfasano', 1, 1615218032, 'COMMENTED'],
#  [25853, 'andfasano', 'deads2k', 1, 1615816432, 'COMMENTED'],
#  [25853, 'andfasano', 'andfasano', 1, 1615817767, 'COMMENTED'],
#  [25848, 'damemi', 'damemi', 21, 1612288095, 'COMMENTED'],
#  [25848, 'damemi', 'soltysh', 1, 1612795006, 'APPROVED'],
#  [25845, 'gabemontero', 'adambkaplan', 21, 1612285001, 'APPROVED'],
#  [25844, 'sgreene570', 'soltysh', 16, 1612265377, 'APPROVED'],
#  [25838, 'gabemontero', 'adambkaplan', 4, 1611946014, 'COMMENTED'],
#  [25836, 'candita', 'Miciah', 1, 1611953700, 'COMMENTED'],
#  [25836, 'candita', 'frobware', 1, 1612536151, 'COMMENTED'],
#  [25836, 'candita', 'frobware', 1, 1612536322, 'COMMENTED'],
#  [25836, 'candita', 'candita', 1, 1612536365, 'COMMENTED'],
#  [25836, 'candita', 'frobware', 1, 1612537668, 'COMMENTED'],
#  [25836, 'candita', 'candita', 1, 1612539526, 'COMMENTED'],
#  [25835, 'smarterclayton', 'Miciah', 1, 1611855802, 'COMMENTED'],
#  [25835, 'smarterclayton', 'smarterclayton', 1, 1611858829, 'COMMENTED'],
#  [25834, 'smarterclayton', 'wking', 1, 1611850442, 'COMMENTED'],
#  [25834, 'smarterclayton', 'smarterclayton', 1, 1611856609, 'COMMENTED'],
#  [25834, 'smarterclayton', 'wking', 1, 1612843285, 'COMMENTED'],
#  [25831, 'openshift-cherrypick-robot', 'soltysh', 1, 1611819907, 'APPROVED'],
#  [25830, 'adambkaplan', 'gabemontero', 1, 1611773634, 'COMMENTED'],
#  [25830, 'adambkaplan', 'adambkaplan', 1, 1611776453, 'COMMENTED'],
#  [25830, 'adambkaplan', 'nalind', 1, 1611777938, 'COMMENTED'],
#  [25828, 'ehashman', 'smarterclayton', 1, 1611936354, 'COMMENTED'],
#  [25828, 'ehashman', 'ehashman', 1, 1611947238, 'COMMENTED'],
#  [25825, 'abhat', 'danwinship', 1, 1611948696, 'COMMENTED'],
#  [25825, 'abhat', 'abhat', 1, 1612011919, 'COMMENTED'],
#  [25820, 'ingvagabund', 'soltysh', 1, 1611571294, 'APPROVED'],
#  [25819, 'deads2k', 'smarterclayton', 1, 1611879930, 'COMMENTED'],
#  [25819, 'deads2k', 'smarterclayton', 1, 1611885755, 'COMMENTED'],
#  [25819, 'deads2k', 'smarterclayton', 1, 1611890762, 'COMMENTED'],
#  [25818, 'danwinship', 'aojea', 1, 1613402688, 'COMMENTED'],
#  [25818, 'danwinship', 'aojea', 1, 1613402732, 'COMMENTED'],
#  [25818, 'danwinship', 'smarterclayton', 1, 1613404282, 'COMMENTED'],
#  [25818, 'danwinship', 'smarterclayton', 1, 1613404520, 'COMMENTED'],
#  [25818, 'danwinship', 'danwinship', 1, 1614708338, 'COMMENTED'],
#  [25818, 'danwinship', 'smarterclayton', 1, 1617041713, 'COMMENTED'],
#  [25818, 'danwinship', 'danwinship', 1, 1617194831, 'COMMENTED'],
#  [25818, 'danwinship', 'smarterclayton', 1, 1618228865, 'COMMENTED'],
#  [25818, 'danwinship', 'smarterclayton', 1, 1618228908, 'COMMENTED'],
#  [25818, 'danwinship', 'smarterclayton', 1, 1618228981, 'COMMENTED'],
#  [25818, 'danwinship', 'smarterclayton', 1, 1618229026, 'COMMENTED'],
#  [25818, 'danwinship', 'smarterclayton', 1, 1618229106, 'COMMENTED'],
#  [25818, 'danwinship', 'smarterclayton', 1, 1618229162, 'COMMENTED'],
#  [25816,
#   'openshift-cherrypick-robot',
#   'adambkaplan',
#   1,
#   1611250011,
#   'APPROVED'],
#  [25815, 'qinpingli', 'mandre', 1, 1612543939, 'COMMENTED'],
#  [25815, 'qinpingli', 'qinpingli', 1, 1612675981, 'COMMENTED'],
#  [25815, 'qinpingli', 'qinpingli', 1, 1612678255, 'COMMENTED'],
#  [25815, 'qinpingli', 'qinpingli', 1, 1612678390, 'COMMENTED'],
#  [25815, 'qinpingli', 'mandre', 1, 1612776299, 'COMMENTED'],
#  [25815, 'qinpingli', 'qinpingli', 1, 1612780067, 'COMMENTED'],
#  [25815, 'qinpingli', 'mandre', 1, 1612788600, 'COMMENTED'],
#  [25815, 'qinpingli', 'qinpingli', 1, 1612832102, 'COMMENTED'],
#  [25812, 'omertuc', 'mrunalp', 1, 1611167987, 'COMMENTED'],
#  [25812, 'omertuc', 'deads2k', 1, 1611168360, 'COMMENTED'],
#  [25812, 'omertuc', 'omertuc', 1, 1611168559, 'COMMENTED'],
#  [25812, 'omertuc', 'deads2k', 1, 1611168784, 'COMMENTED'],
#  [25812, 'omertuc', 'omertuc', 1, 1611169265, 'COMMENTED'],
#  [25812, 'omertuc', 'romfreiman', 1, 1611211864, 'COMMENTED'],
#  [25812, 'omertuc', 'ravidbro', 1, 1611223684, 'COMMENTED'],
#  [25812, 'omertuc', 'omertuc', 1, 1611224160, 'COMMENTED'],
#  [25812, 'omertuc', 'ravidbro', 1, 1611225180, 'COMMENTED'],
#  [25812, 'omertuc', 'omertuc', 1, 1611225524, 'COMMENTED'],
#  [25812, 'omertuc', 'markmc', 1, 1612452352, 'COMMENTED'],
#  [25812, 'omertuc', 'omertuc', 1, 1612452841, 'COMMENTED'],
#  [25812, 'omertuc', 'omertuc', 1, 1612452999, 'COMMENTED'],
#  [25812, 'omertuc', 'omertuc', 1, 1612453045, 'COMMENTED'],
#  [25812, 'omertuc', 'omertuc', 1, 1612454210, 'COMMENTED'],
#  [25812, 'omertuc', 'omertuc', 1, 1612454326, 'COMMENTED'],
#  [25812, 'omertuc', 'sttts', 1, 1612863498, 'COMMENTED'],
#  [25812, 'omertuc', 'sttts', 1, 1612863510, 'COMMENTED'],
#  [25812, 'omertuc', 'omertuc', 1, 1612864157, 'COMMENTED'],
#  [25812, 'omertuc', 'omertuc', 1, 1612864284, 'COMMENTED'],
#  [25812, 'omertuc', 'simonpasquier', 16, 1612948632, 'COMMENTED'],
#  [25810, 'gabemontero', 'bparees', 1, 1611177453, 'COMMENTED'],
#  [25810, 'gabemontero', 'gabemontero', 1, 1611177704, 'COMMENTED'],
#  [25810, 'gabemontero', 'gabemontero', 1, 1611177813, 'COMMENTED'],
#  [25809, 'ingvagabund', 'soltysh', 10, 1611058813, 'CHANGES_REQUESTED'],
#  [25809, 'ingvagabund', 'soltysh', 1, 1611140654, 'APPROVED'],
#  [25808, 'stlaz', 'soltysh', 1, 1611049360, 'APPROVED'],
#  [25798, 'gabemontero', 'xiuwang', 1, 1610693590, 'COMMENTED'],
#  [25795, 'damemi', 'damemi', 4, 1610566886, 'COMMENTED'],
#  [25791, 'p0lyn0mial', 'p0lyn0mial', 1, 1610527526, 'COMMENTED'],
#  [25791, 'p0lyn0mial', 'p0lyn0mial', 1, 1610527588, 'COMMENTED'],
#  [25791, 'p0lyn0mial', 'sttts', 1, 1610530268, 'COMMENTED'],
#  [25791, 'p0lyn0mial', 'p0lyn0mial', 1, 1610537304, 'COMMENTED'],
#  [25791, 'p0lyn0mial', 'sttts', 1, 1610612118, 'COMMENTED'],
#  [25791, 'p0lyn0mial', 'p0lyn0mial', 1, 1610614805, 'COMMENTED'],
#  [25791, 'p0lyn0mial', 'p0lyn0mial', 1, 1610615019, 'COMMENTED'],
#  [25788, 'openshift-bot', 'soltysh', 1, 1612432456, 'APPROVED'],
#  [25786, 'jaypoulz', 'ricardomaraschini', 1, 1610378774, 'APPROVED'],
#  [25781, 'ingvagabund', 'soltysh', 1, 1610386954, 'APPROVED'],
#  [25780, 'stlaz', 'marun', 3, 1609948087, 'COMMENTED'],
#  [25780, 'stlaz', 'stlaz', 1, 1610015926, 'COMMENTED'],
#  [25780, 'stlaz', 'sttts', 1, 1610359660, 'COMMENTED'],
#  [25780, 'stlaz', 'sttts', 1, 1610359745, 'COMMENTED'],
#  [25780, 'stlaz', 'stlaz', 1, 1610360079, 'COMMENTED'],
#  [25780, 'stlaz', 'stlaz', 1, 1610360691, 'COMMENTED'],
#  [25775, 'gnufied', 'tnozicka', 1, 1608302569, 'APPROVED'],
#  [25774, 'marun', 'smarterclayton', 1, 1617286750, 'COMMENTED'],
#  [25774, 'marun', 'marun', 1, 1617287258, 'COMMENTED'],
#  [25773, 'p0lyn0mial', 'soltysh', 1, 1608218293, 'APPROVED'],
#  [25772, 'smarterclayton', 'soltysh', 1, 1608214582, 'APPROVED'],
#  [25769, 'smarterclayton', 'soltysh', 1, 1608043050, 'APPROVED'],
#  [25769, 'smarterclayton', 'soltysh', 1, 1608044676, 'APPROVED'],
#  [25769, 'smarterclayton', 'bparees', 1, 1608044911, 'COMMENTED'],
#  [25769, 'smarterclayton', 'bparees', 1, 1608044978, 'COMMENTED'],
#  [25766, 'marun', 'wking', 1, 1607998800, 'APPROVED'],
#  [25764, 'tnozicka', 'soltysh', 1, 1608024857, 'APPROVED'],
#  [25764, 'tnozicka', 'tnozicka', 1, 1608128013, 'COMMENTED'],
#  [25764, 'tnozicka', 'soltysh', 1, 1608132591, 'APPROVED'],
#  [25756, 'jhadvig', 'spadgett', 1, 1607627483, 'APPROVED'],
#  [25755, 'sjenning', 'deads2k', 1, 1607624848, 'COMMENTED'],
#  [25755, 'sjenning', 'deads2k', 1, 1607624878, 'COMMENTED'],
#  [25754, 'gabemontero', 'adambkaplan', 1, 1607691520, 'CHANGES_REQUESTED'],
#  [25754, 'gabemontero', 'gabemontero', 1, 1607692418, 'COMMENTED'],
#  [25754, 'gabemontero', 'gabemontero', 1, 1607696402, 'COMMENTED'],
#  [25754, 'gabemontero', 'gabemontero', 1, 1607696783, 'COMMENTED'],
#  [25754, 'gabemontero', 'gabemontero', 1, 1607696813, 'COMMENTED'],
#  [25754, 'gabemontero', 'adambkaplan', 1, 1607697367, 'APPROVED'],
#  [25750, 'smarterclayton', 'marun', 1, 1607479187, 'COMMENTED'],
#  [25750, 'smarterclayton', 'smarterclayton', 1, 1607519169, 'COMMENTED'],
#  [25750, 'smarterclayton', 'marun', 1, 1607531077, 'COMMENTED'],
#  [25750, 'smarterclayton', 'smarterclayton', 1, 1607532536, 'COMMENTED'],
#  [25746, 'soltysh', 'adambkaplan', 10, 1607361679, 'COMMENTED'],
#  [25746, 'soltysh', 'soltysh', 1, 1607426133, 'COMMENTED'],
#  [25746, 'soltysh', 'soltysh', 1, 1607426317, 'COMMENTED'],
#  [25746, 'soltysh', 'adambkaplan', 1, 1607453102, 'COMMENTED'],
#  [25746, 'soltysh', 'soltysh', 1, 1607612494, 'COMMENTED'],
#  [25746, 'soltysh', 'adambkaplan', 1, 1611756627, 'APPROVED'],
#  [25745, 'gabemontero', 'gabemontero', 1, 1607715123, 'COMMENTED'],
#  [25745, 'gabemontero', 'gabemontero', 1, 1607722890, 'COMMENTED'],
#  [25745, 'gabemontero', 'bparees', 1, 1608045550, 'COMMENTED'],
#  [25745, 'gabemontero', 'gabemontero', 1, 1608046126, 'COMMENTED'],
#  [25742, 'Joseph-Goergen', 'csrwng', 5, 1607109896, 'COMMENTED'],
#  [25740, 'gabemontero', 'adambkaplan', 1, 1607447150, 'APPROVED'],
#  [25738, 'stlaz', 'stlaz', 1, 1607091317, 'COMMENTED'],
#  [25738, 'stlaz', 'sallyom', 1, 1607604238, 'COMMENTED'],
#  [25738, 'stlaz', 'sallyom', 1, 1607604339, 'COMMENTED'],
#  [25738, 'stlaz', 'sallyom', 1, 1607604566, 'COMMENTED'],
#  [25738, 'stlaz', 'soltysh', 4, 1608027818, 'CHANGES_REQUESTED'],
#  [25738, 'stlaz', 'stlaz', 1, 1609758789, 'COMMENTED'],
#  [25738, 'stlaz', 'stlaz', 1, 1609763624, 'COMMENTED'],
#  [25738, 'stlaz', 'soltysh', 1, 1610624712, 'APPROVED'],
#  [25738, 'stlaz', 'soltysh', 2, 1610976315, 'APPROVED'],
#  [25737, 'tnozicka', 'soltysh', 1, 1607002153, 'APPROVED'],
#  [25735, 'ingvagabund', 'soltysh', 1, 1606992317, 'APPROVED'],
#  [25733, 'jsafrane', 'tsmetana', 1, 1606992885, 'APPROVED'],
#  [25732, 'ingvagabund', 'soltysh', 1, 1606920483, 'APPROVED'],
#  [25731, 'tnozicka', 'soltysh', 1, 1606921729, 'APPROVED'],
#  [25730, 'tnozicka', 'sttts', 1, 1606908535, 'COMMENTED'],
#  [25730, 'tnozicka', 'sttts', 1, 1606908570, 'COMMENTED'],
#  [25730, 'tnozicka', 'tnozicka', 1, 1606908643, 'COMMENTED'],
#  [25730, 'tnozicka', 'sttts', 1, 1606988397, 'COMMENTED'],
#  [25730, 'tnozicka', 'sttts', 1, 1606988464, 'COMMENTED'],
#  [25730, 'tnozicka', 'tnozicka', 1, 1606989780, 'COMMENTED'],
#  [25729,
#   'openshift-cherrypick-robot',
#   'adambkaplan',
#   1,
#   1606913857,
#   'APPROVED'],
#  [25725, 'ingvagabund', 'soltysh', 1, 1606819920, 'APPROVED'],
#  [25723, 'marun', 'smarterclayton', 1, 1607455609, 'COMMENTED'],
#  [25723, 'marun', 'marun', 1, 1607474989, 'COMMENTED'],
#  [25723, 'marun', 'marun', 1, 1607480162, 'COMMENTED'],
#  [25723, 'marun', 'smarterclayton', 1, 1612200362, 'COMMENTED'],
#  [25723, 'marun', 'smarterclayton', 1, 1612200815, 'COMMENTED'],
#  [25723, 'marun', 'smarterclayton', 1, 1612200891, 'COMMENTED'],
#  [25723, 'marun', 'marun', 1, 1612277375, 'COMMENTED'],
#  [25723, 'marun', 'marun', 1, 1612550933, 'COMMENTED'],
#  [25723, 'marun', 'hexfusion', 19, 1612558366, 'COMMENTED'],
#  [25723, 'marun', 'hexfusion', 1, 1612558498, 'COMMENTED'],
#  [25723, 'marun', 'marun', 1, 1612560507, 'COMMENTED'],
#  [25723, 'marun', 'marun', 1, 1612560532, 'COMMENTED'],
#  [25723, 'marun', 'marun', 1, 1612560635, 'COMMENTED'],
#  [25722, 'sadasu', 'soltysh', 85, 1606812756, 'CHANGES_REQUESTED'],
#  [25721, 'gabemontero', 'coreydaley', 1, 1607959924, 'COMMENTED'],
#  [25721, 'gabemontero', 'gabemontero', 1, 1607960136, 'COMMENTED'],
#  [25721, 'gabemontero', 'coreydaley', 15, 1607960149, 'COMMENTED'],
#  [25721, 'gabemontero', 'coreydaley', 1, 1607960186, 'COMMENTED'],
#  [25721, 'gabemontero', 'adambkaplan', 1, 1607960205, 'APPROVED'],
#  [25721, 'gabemontero', 'gabemontero', 1, 1607960319, 'COMMENTED'],
#  [25715, 'ingvagabund', 'soltysh', 1, 1606738564, 'APPROVED'],
#  [25708, 'soltysh', 'soltysh', 1, 1606228424, 'COMMENTED'],
#  [25707, 'marun', 'smarterclayton', 1, 1607963854, 'COMMENTED'],
#  [25707, 'marun', 'marun', 1, 1607970945, 'COMMENTED'],
#  [25705, 'Danil-Grigorev', 'JoelSpeed', 1, 1606139654, 'COMMENTED'],
#  [25704, 'ingvagabund', 'soltysh', 1, 1606126453, 'APPROVED'],
#  [25704, 'ingvagabund', 'soltysh', 1, 1606132916, 'APPROVED'],
#  [25702, 'dmage', 'wking', 1, 1605902800, 'APPROVED'],
#  [25702, 'dmage', 'soltysh', 1, 1605904079, 'APPROVED'],
#  [25701, 'vrutkovs', 'soltysh', 1, 1606133290, 'APPROVED'],
#  [25700, 'hexfusion', 'soltysh', 1, 1606134820, 'APPROVED'],
#  [25699, 'marun', 'p0lyn0mial', 1, 1606211438, 'COMMENTED'],
#  [25699, 'marun', 'marun', 1, 1606276099, 'COMMENTED'],
#  [25691, 'vareti', 'marun', 1, 1605544484, 'COMMENTED'],
#  [25691, 'vareti', 'vareti', 1, 1605545518, 'COMMENTED'],
#  [25691, 'vareti', 'marun', 127, 1605621411, 'COMMENTED'],
#  [25690, 'ricardomaraschini', 'dmage', 1, 1605710261, 'COMMENTED'],
#  [25690, 'ricardomaraschini', 'ricardomaraschini', 1, 1605790365, 'COMMENTED'],
#  [25688, 'fromanirh', 'adambkaplan', 1, 1606219980, 'COMMENTED'],
#  [25688, 'fromanirh', 'fromanirh', 1, 1606220157, 'COMMENTED'],
#  [25688, 'fromanirh', 'adambkaplan', 1, 1606231962, 'COMMENTED'],
#  [25688, 'fromanirh', 'fromanirh', 1, 1606232097, 'COMMENTED'],
#  [25688, 'fromanirh', 'fromanirh', 1, 1606233550, 'COMMENTED'],
#  [25688, 'fromanirh', 'adambkaplan', 6, 1606318792, 'COMMENTED'],
#  [25688, 'fromanirh', 'adambkaplan', 1, 1606754323, 'APPROVED'],
#  [25683, 'joelsmith', 'giuseppe', 1, 1605293019, 'APPROVED'],
#  [25679, 'dmage', 'soltysh', 1, 1605187709, 'APPROVED'],
#  [25678, 'dmage', 'soltysh', 16, 1605187962, 'APPROVED'],
#  [25674, 'p0lyn0mial', 'p0lyn0mial', 1, 1605002935, 'COMMENTED'],
#  [25674, 'p0lyn0mial', 'sttts', 1, 1605003182, 'COMMENTED'],
#  [25674, 'p0lyn0mial', 'sttts', 1, 1605003238, 'COMMENTED'],
#  [25674, 'p0lyn0mial', 'sttts', 1, 1605003263, 'COMMENTED'],
#  [25674, 'p0lyn0mial', 'p0lyn0mial', 1, 1605007379, 'COMMENTED'],
#  [25674, 'p0lyn0mial', 'p0lyn0mial', 1, 1605007399, 'COMMENTED'],
#  [25674, 'p0lyn0mial', 'p0lyn0mial', 1, 1605007493, 'COMMENTED'],
#  [25674, 'p0lyn0mial', 'p0lyn0mial', 1, 1605025461, 'COMMENTED'],
#  [25674, 'p0lyn0mial', 'p0lyn0mial', 1, 1605775114, 'COMMENTED'],
#  [25674, 'p0lyn0mial', 'tkashem', 1, 1606857125, 'COMMENTED'],
#  [25674, 'p0lyn0mial', 'p0lyn0mial', 1, 1606995284, 'COMMENTED'],
#  [25674, 'p0lyn0mial', 'p0lyn0mial', 1, 1606995295, 'COMMENTED'],
#  [25674, 'p0lyn0mial', 'p0lyn0mial', 1, 1606995299, 'COMMENTED'],
#  [25673, 'soltysh', 'wking', 1, 1605011671, 'APPROVED'],
#  [25671, 'gabemontero', 'gabemontero', 1, 1604965550, 'COMMENTED'],
#  [25661, 'gabemontero', 'adambkaplan', 42, 1604684802, 'CHANGES_REQUESTED'],
#  [25661, 'gabemontero', 'gabemontero', 1, 1604684945, 'COMMENTED'],
#  [25661, 'gabemontero', 'gabemontero', 1, 1604685006, 'COMMENTED'],
#  [25661, 'gabemontero', 'bparees', 1, 1604687000, 'COMMENTED'],
#  [25661, 'gabemontero', 'gabemontero', 1, 1604687693, 'COMMENTED'],
#  [25661, 'gabemontero', 'gabemontero', 1, 1604687851, 'COMMENTED'],
#  [25661, 'gabemontero', 'gabemontero', 1, 1604687944, 'COMMENTED'],
#  [25661, 'gabemontero', 'gabemontero', 1, 1604688102, 'COMMENTED'],
#  [25661, 'gabemontero', 'bparees', 1, 1604689359, 'COMMENTED'],
#  [25661, 'gabemontero', 'gabemontero', 1, 1604689561, 'COMMENTED'],
#  [25661, 'gabemontero', 'bparees', 1, 1604690245, 'COMMENTED'],
#  [25661, 'gabemontero', 'adambkaplan', 1, 1604925033, 'APPROVED'],
#  [25660, 'p0lyn0mial', 'p0lyn0mial', 1, 1604398664, 'COMMENTED'],
#  [25660, 'p0lyn0mial', 'p0lyn0mial', 1, 1604398731, 'COMMENTED'],
#  [25659, 'tnozicka', 'soltysh', 1, 1604399214, 'APPROVED'],
#  [25656, 'p0lyn0mial', 'JAORMX', 1, 1604401310, 'APPROVED'],
#  [25655, 'Fedosin', 'mandre', 1, 1604389574, 'COMMENTED'],
#  [25654,
#   'openshift-cherrypick-robot',
#   'adambkaplan',
#   1,
#   1604924607,
#   'APPROVED'],
#  [25652, 'marun', 'sttts', 1, 1604302091, 'COMMENTED'],
#  [25652, 'marun', 'sttts', 1, 1604302371, 'COMMENTED'],
#  [25652, 'marun', 'p0lyn0mial', 1, 1604304087, 'COMMENTED'],
#  [25652, 'marun', 'sttts', 1, 1604306419, 'COMMENTED'],
#  [25652, 'marun', 'p0lyn0mial', 1, 1604315312, 'COMMENTED'],
#  [25652, 'marun', 'p0lyn0mial', 1, 1604315475, 'COMMENTED'],
#  [25652, 'marun', 'sttts', 1, 1604320281, 'COMMENTED'],
#  [25652, 'marun', 'marun', 1, 1604329943, 'COMMENTED'],
#  [25652, 'marun', 'marun', 1, 1604329966, 'COMMENTED'],
#  [25652, 'marun', 'marun', 1, 1604330034, 'COMMENTED'],
#  [25652, 'marun', 'marun', 1, 1604985869, 'COMMENTED'],
#  [25650, 'gabemontero', 'adambkaplan', 1, 1604316829, 'APPROVED'],
#  [25647, 'gabemontero', 'adambkaplan', 15, 1603995435, 'APPROVED'],
#  [25647, 'gabemontero', 'adambkaplan', 1, 1604319868, 'APPROVED'],
#  [25645, 'p0lyn0mial', 'soltysh', 1, 1603982224, 'APPROVED'],
#  [25644, 'gabemontero', 'soltysh', 1, 1603975239, 'APPROVED'],
#  [25640, 'gabemontero', 'adambkaplan', 14, 1603897282, 'APPROVED'],
#  [25633, 'dmage', 'ricardomaraschini', 1, 1603782372, 'APPROVED'],
#  [25632, 'p0lyn0mial', 'soltysh', 1, 1603722916, 'APPROVED'],
#  [25631, 'p0lyn0mial', 'soltysh', 1, 1603722908, 'APPROVED'],
#  [25630, 'e-minguez', 'jmencak', 1, 1610374840, 'APPROVED'],
#  [25630, 'e-minguez', 'jmencak', 1, 1618206885, 'APPROVED'],
#  [25625, 'coreydaley', 'adambkaplan', 33, 1603481672, 'COMMENTED'],
#  [25625, 'coreydaley', 'adambkaplan', 5, 1603897889, 'COMMENTED'],
#  [25625, 'coreydaley', 'adambkaplan', 1, 1603898115, 'COMMENTED'],
#  [25625, 'coreydaley', 'coreydaley', 1, 1603898163, 'COMMENTED'],
#  [25625, 'coreydaley', 'coreydaley', 1, 1603898176, 'COMMENTED'],
#  [25625, 'coreydaley', 'coreydaley', 1, 1603898253, 'COMMENTED'],
#  [25625, 'coreydaley', 'coreydaley', 1, 1603898374, 'COMMENTED'],
#  [25625, 'coreydaley', 'adambkaplan', 1, 1603900749, 'APPROVED'],
#  [25625, 'coreydaley', 'soltysh', 2, 1603965613, 'CHANGES_REQUESTED'],
#  [25625, 'coreydaley', 'coreydaley', 1, 1603970503, 'COMMENTED'],
#  [25625, 'coreydaley', 'soltysh', 1, 1603970824, 'APPROVED'],
#  [25620, 'deads2k', 'sttts', 1, 1603346533, 'COMMENTED'],
#  [25614, 'jsafrane', 'gnufied', 1, 1603762355, 'COMMENTED'],
#  [25614, 'jsafrane', 'gnufied', 1, 1603763040, 'COMMENTED'],
#  [25614, 'jsafrane', 'gnufied', 1, 1603763082, 'COMMENTED'],
#  [25614, 'jsafrane', 'jsafrane', 1, 1603786010, 'COMMENTED'],
#  [25614, 'jsafrane', 'jsafrane', 1, 1603965669, 'COMMENTED'],
#  [25614, 'jsafrane', 'jsafrane', 1, 1603965945, 'COMMENTED'],
#  [25614, 'jsafrane', 'bertinatto', 1, 1603967102, 'COMMENTED'],
#  [25614, 'jsafrane', 'simonpasquier', 1, 1603974883, 'COMMENTED'],
#  [25614, 'jsafrane', 'jsafrane', 1, 1603989881, 'COMMENTED'],
#  [25614, 'jsafrane', 'soltysh', 1, 1604054923, 'APPROVED'],
#  [25608, 'deads2k', 'sttts', 1, 1603090613, 'COMMENTED'],
#  [25608, 'deads2k', 'sttts', 1, 1603090633, 'COMMENTED'],
#  [25606, 'aojea', 'aojea', 1, 1602601297, 'COMMENTED'],
#  [25606, 'aojea', 'aojea', 1, 1602770459, 'COMMENTED'],
#  [25603, 'damemi', 'soltysh', 1, 1604569544, 'APPROVED'],
#  [25602, 'jsafrane', 'deads2k', 1, 1602508170, 'COMMENTED'],
#  [25602, 'jsafrane', 'deads2k', 1, 1602508375, 'COMMENTED'],
#  [25602, 'jsafrane', 'deads2k', 1, 1602508445, 'COMMENTED'],
#  [25602, 'jsafrane', 'deads2k', 1, 1602508508, 'COMMENTED'],
#  [25602, 'jsafrane', 'deads2k', 1, 1602508603, 'COMMENTED'],
#  [25602, 'jsafrane', 'jsafrane', 1, 1602509232, 'COMMENTED'],
#  [25602, 'jsafrane', 'jsafrane', 1, 1602509485, 'COMMENTED'],
#  [25602, 'jsafrane', 'jsafrane', 1, 1602510187, 'COMMENTED'],
#  [25602, 'jsafrane', 'jsafrane', 1, 1602510220, 'COMMENTED'],
#  [25602, 'jsafrane', 'jsafrane', 1, 1602570690, 'COMMENTED'],
#  [25602, 'jsafrane', 'jsafrane', 1, 1602571845, 'COMMENTED'],
#  [25602, 'jsafrane', 'deads2k', 1, 1603998709, 'COMMENTED'],
#  [25598,
#   'openshift-cherrypick-robot',
#   'adambkaplan',
#   6,
#   1603906977,
#   'APPROVED'],
#  [25596, 'deads2k', 'bparees', 1, 1602190116, 'COMMENTED'],
#  [25596, 'deads2k', 'smarterclayton', 1, 1602190251, 'COMMENTED'],
#  [25595, 'gabemontero', 'adambkaplan', 45, 1603287417, 'COMMENTED'],
#  [25595, 'gabemontero', 'bparees', 1, 1603296925, 'COMMENTED'],
#  [25595, 'gabemontero', 'gabemontero', 1, 1603297230, 'COMMENTED'],
#  [25595, 'gabemontero', 'adambkaplan', 1, 1603297450, 'APPROVED'],
#  [25592, 'smarterclayton', 'lilic', 1, 1602566388, 'COMMENTED'],
#  [25583, 'yselkowitz', 'sgreene570', 1, 1601987754, 'COMMENTED'],
#  [25583, 'yselkowitz', 'yselkowitz', 1, 1601987890, 'COMMENTED'],
#  [25583, 'yselkowitz', 'sgreene570', 1, 1601987993, 'COMMENTED'],
#  [25579, 'jsafrane', 'bertinatto', 1, 1601626969, 'COMMENTED'],
#  [25575, 'mfojtik', 'deads2k', 1, 1601546661, 'COMMENTED'],
#  [25575, 'mfojtik', 'mfojtik', 1, 1601546705, 'COMMENTED'],
#  [25562, 'ironcladlou', 'wking', 1, 1601317582, 'COMMENTED'],
#  [25562, 'ironcladlou', 'smarterclayton', 1, 1601317912, 'COMMENTED'],
#  [25562, 'ironcladlou', 'ironcladlou', 1, 1601317924, 'COMMENTED'],
#  [25562, 'ironcladlou', 'ironcladlou', 1, 1601317952, 'COMMENTED'],
#  [25562, 'ironcladlou', 'wking', 1, 1601318131, 'COMMENTED'],
#  [25562, 'ironcladlou', 'ironcladlou', 1, 1601377724, 'COMMENTED'],
#  [25561, 'vareti', 'p0lyn0mial', 1, 1601299223, 'COMMENTED'],
#  [25561, 'vareti', 'p0lyn0mial', 1, 1601299240, 'COMMENTED'],
#  [25561, 'vareti', 'p0lyn0mial', 1, 1601299248, 'COMMENTED'],
#  [25561, 'vareti', 'vareti', 1, 1601311595, 'COMMENTED'],
#  [25561, 'vareti', 'vareti', 1, 1601311613, 'COMMENTED'],
#  [25561, 'vareti', 'p0lyn0mial', 1, 1601315167, 'COMMENTED'],
#  [25561, 'vareti', 'soltysh', 1, 1601357782, 'APPROVED'],
#  [25560, 'soltysh', 'damemi', 1, 1601290692, 'APPROVED'],
#  [25559, 'soltysh', 'sttts', 1, 1601285223, 'COMMENTED'],
#  [25559, 'soltysh', 'deads2k', 1, 1601287186, 'COMMENTED'],
#  [25559, 'soltysh', 'soltysh', 1, 1601287786, 'COMMENTED'],
#  [25559, 'soltysh', 'sttts', 1, 1601288231, 'COMMENTED'],
#  [25553, 'wking', 'wking', 1, 1600982746, 'COMMENTED'],
#  [25553, 'wking', 'wking', 1, 1600982764, 'COMMENTED'],
#  [25553, 'wking', 'wking', 1, 1600982772, 'COMMENTED'],
#  [25553, 'wking', 'wking', 1, 1600982779, 'COMMENTED'],
#  [25553, 'wking', 'wking', 1, 1600983011, 'COMMENTED'],
#  [25553, 'wking', 'wking', 1, 1600983017, 'COMMENTED'],
#  [25553, 'wking', 'wking', 1, 1600983024, 'COMMENTED'],
#  [25553, 'wking', 'wking', 1, 1600983029, 'COMMENTED'],
#  [25552, 'yselkowitz', 'adambkaplan', 1, 1602027261, 'APPROVED'],
#  [25549, 'michaelgugino', 'elmiko', 26, 1600946983, 'APPROVED'],
#  [25543, 'damemi', 'soltysh', 1, 1600934263, 'APPROVED'],
#  [25542, 'miheer', 'frobware', 1, 1603983388, 'COMMENTED'],
#  [25541, 'damemi', 'soltysh', 1, 1600929265, 'APPROVED'],
#  [25539, 'gabemontero', 'yselkowitz', 1, 1600814125, 'CHANGES_REQUESTED'],
#  [25539, 'gabemontero', 'gabemontero', 1, 1600815135, 'COMMENTED'],
#  [25539, 'gabemontero', 'adambkaplan', 1, 1600862951, 'APPROVED'],
#  [25537, 'arnongilboa', 'jsafrane', 37, 1600771525, 'COMMENTED'],
#  [25537, 'arnongilboa', 'soltysh', 1, 1600848268, 'APPROVED'],
#  [25536, 'tnozicka', 'soltysh', 1, 1600762265, 'APPROVED'],
#  [25528, 'yselkowitz', 'adambkaplan', 33, 1600778707, 'COMMENTED'],
#  [25528, 'yselkowitz', 'adambkaplan', 1, 1600862987, 'APPROVED'],
#  [25525, 'hexfusion', 'hexfusion', 1, 1600453984, 'COMMENTED'],
#  [25525, 'hexfusion', 'hexfusion', 1, 1600455057, 'COMMENTED'],
#  [25525, 'hexfusion', 'hexfusion', 1, 1600455684, 'COMMENTED'],
#  [25524, 'hexfusion', 'deads2k', 1, 1600433044, 'CHANGES_REQUESTED'],
#  [25524, 'hexfusion', 'hexfusion', 1, 1600433161, 'COMMENTED'],
#  [25523, 'vrutkovs', 'kevinrizza', 1, 1600436129, 'COMMENTED'],
#  [25523, 'vrutkovs', 'vrutkovs', 1, 1600440377, 'COMMENTED'],
#  [25523, 'vrutkovs', 'vrutkovs', 1, 1600440429, 'COMMENTED'],
#  [25523, 'vrutkovs', 'smarterclayton', 1, 1600446779, 'COMMENTED'],
# ...
#  [25523, 'vrutkovs', 'vrutkovs', 1, 1600702275, 'COMMENTED'],
#  [25523, 'vrutkovs', 'smarterclayton', 1, 1600705810, 'COMMENTED'],
#  [25522, 'jmcmeek', 'rtheis', 1, 1600413928, 'APPROVED'],
#  [25521, 'jmcmeek', 'rtheis', 1, 1600413924, 'APPROVED'],
#  [25520, 'jmcmeek', 'rtheis', 1, 1600413917, 'APPROVED'],
#  [25517, 'kevinrizza', 'dinhxuanvu', 1, 1600347521, 'APPROVED'],
#  [25503, 'umohnani8', 'cgwalters', 1, 1600288694, 'APPROVED'],
#  [25494, 'tbielawa', 'soltysh', 1, 1600089854, 'APPROVED'],
#  [25485, 'pedjak', 'pedjak', 1, 1599562005, 'COMMENTED'],
#  [25485, 'pedjak', 'jhadvig', 1, 1599748154, 'APPROVED'],
#  [25483, 'arnongilboa', 'smarterclayton', 1, 1599741228, 'COMMENTED'],
#  [25483, 'arnongilboa', 'smarterclayton', 1, 1599741242, 'COMMENTED'],
#  [25483, 'arnongilboa', 'smarterclayton', 1, 1599741299, 'COMMENTED'],
#  [25483, 'arnongilboa', 'smarterclayton', 1, 1599741399, 'COMMENTED'],
#  [25483, 'arnongilboa', 'smarterclayton', 1, 1600172944, 'COMMENTED'],
#  [25483, 'arnongilboa', 'jsafrane', 1, 1600686129, 'COMMENTED'],
#  [25483, 'arnongilboa', 'arnongilboa', 1, 1600687935, 'COMMENTED'],
#  [25472, 'gabemontero', 'gabemontero', 1, 1599139938, 'COMMENTED'],
#  [25472, 'gabemontero', 'bparees', 1, 1599140060, 'COMMENTED'],
#  [25472, 'gabemontero', 'bparees', 1, 1599140212, 'COMMENTED'],
#  [25472, 'gabemontero', 'gabemontero', 1, 1599140254, 'COMMENTED'],
#  [25472, 'gabemontero', 'gabemontero', 1, 1599140372, 'COMMENTED'],
#  [25472, 'gabemontero', 'gabemontero', 1, 1599140406, 'COMMENTED'],
#  [25471, 'tsmetana', 'deads2k', 1, 1602166299, 'COMMENTED'],
#  [25471, 'tsmetana', 'deads2k', 1, 1602169083, 'COMMENTED'],
#  [25471, 'tsmetana', 'tsmetana', 1, 1602169521, 'COMMENTED'],
#  [25471, 'tsmetana', 'tsmetana', 1, 1602174328, 'COMMENTED'],
#  [25469, 'gabemontero', 'adambkaplan', 1, 1602173704, 'APPROVED'],
#  [25467, 'soltysh', 'damemi', 1, 1599131278, 'APPROVED'],
#  [25463, 'damemi', 'damemi', 34, 1607438049, 'COMMENTED'],
#  [25461, 'ingvagabund', 'soltysh', 1, 1601450015, 'APPROVED'],
#  [25455, 'soltysh', 'tnozicka', 21, 1598872853, 'COMMENTED'],
#  [25454, 'ironcladlou', 'ironcladlou', 1, 1598533438, 'COMMENTED'],
#  [25454, 'ironcladlou', 'hexfusion', 1, 1598534197, 'COMMENTED'],
#  [25454, 'ironcladlou', 'ironcladlou', 1, 1598545041, 'COMMENTED'],
#  [25454, 'ironcladlou', 'smarterclayton', 1, 1598879409, 'COMMENTED'],
#  [25454, 'ironcladlou', 'smarterclayton', 1, 1598879431, 'COMMENTED'],
#  [25449, 'dmage', 'ricardomaraschini', 1, 1598509495, 'APPROVED'],
#  [25448, 'alexanderConstantinescu', 'squeed', 1, 1598451017, 'COMMENTED'],
#  [25448,
#   'alexanderConstantinescu',
#   'alexanderConstantinescu',
#   1,
#   1598454162,
#   'COMMENTED'],
#  [25448, 'alexanderConstantinescu', 'aojea', 1, 1598474788, 'COMMENTED'],
#  [25448,
#   'alexanderConstantinescu',
#   'alexanderConstantinescu',
#   1,
#   1598509622,
#   'COMMENTED'],
#  [25448,
#   'alexanderConstantinescu',
#   'alexanderConstantinescu',
#   1,
#   1598509650,
#   'COMMENTED'],
#  [25448,
#   'alexanderConstantinescu',
#   'alexanderConstantinescu',
#   1,
#   1598509663,
#   'COMMENTED'],
#  [25448, 'alexanderConstantinescu', 'squeed', 1, 1598870323, 'COMMENTED'],
#  [25448,
#   'alexanderConstantinescu',
#   'alexanderConstantinescu',
#   1,
#   1598879436,
#   'COMMENTED'],
#  [25446, 'deads2k', 'sttts', 1, 1598380837, 'COMMENTED'],
#  [25446, 'deads2k', 'deads2k', 1, 1599061350, 'COMMENTED'],
#  [25446, 'deads2k', 'marun', 1, 1599103507, 'COMMENTED'],
#  [25446, 'deads2k', 'sttts', 1, 1599109319, 'COMMENTED'],
#  [25446, 'deads2k', 'tnozicka', 1, 1599111114, 'COMMENTED'],
#  [25446, 'deads2k', 'marun', 1, 1599136002, 'COMMENTED'],
#  [25446, 'deads2k', 'tnozicka', 1, 1599495797, 'COMMENTED'],
#  [25446, 'deads2k', 'sttts', 1, 1599561198, 'COMMENTED'],
#  [25446, 'deads2k', 'sttts', 1, 1599809952, 'COMMENTED'],
#  [25445, 'gabemontero', 'adambkaplan', 1, 1598376176, 'APPROVED'],
#  [25441, 'tnozicka', 'soltysh', 1, 1598345940, 'APPROVED'],
#  [25430, 'ironcladlou', 'wking', 1, 1597938851, 'COMMENTED'],
#  [25430, 'ironcladlou', 'wking', 1, 1597939725, 'COMMENTED'],
#  [25430, 'ironcladlou', 'ironcladlou', 1, 1598376254, 'COMMENTED'],
#  [25429, 's1061123', 'jonesbr17', 1, 1599132870, 'APPROVED'],
#  [25427, 'Danil-Grigorev', 'sttts', 1, 1598450022, 'COMMENTED'],
#  [25427, 'Danil-Grigorev', 'Danil-Grigorev', 1, 1598512621, 'COMMENTED'],
#  [25426, 'soltysh', 'damemi', 3, 1599223734, 'APPROVED'],
#  [25426, 'soltysh', 'damemi', 1, 1599234262, 'APPROVED'],
#  [25425, 'sjenning', 'cgwalters', 1, 1597922788, 'COMMENTED'],
#  [25424, 'damemi', 'soltysh', 1, 1597910934, 'CHANGES_REQUESTED'],
#  [25424, 'damemi', 'damemi', 4, 1597923862, 'COMMENTED'],
#  [25423, 'deads2k', 'sttts', 1, 1597848971, 'COMMENTED'],
#  [25420, 'deads2k', 'bparees', 1, 1597773636, 'COMMENTED'],
#  [25420, 'deads2k', 'bparees', 1, 1597773676, 'COMMENTED'],
#  [25419, 'sjenning', 'cgwalters', 1, 1597787671, 'COMMENTED'],
#  [25409, 'deads2k', 'mfojtik', 1, 1597315241, 'COMMENTED'],
#  [25409, 'deads2k', 'mfojtik', 1, 1597315269, 'COMMENTED'],
#  [25408, 'soltysh', 'tnozicka', 1, 1599794153, 'COMMENTED'],
#  [25408, 'soltysh', 'tnozicka', 1, 1599815193, 'APPROVED'],
#  [25407, 'ingvagabund', 'soltysh', 13, 1598268481, 'APPROVED'],
#  [25403, 'aojea', 'soltysh', 21, 1597224533, 'APPROVED'],
#  [25402, 'marun', 'soltysh', 1, 1597125011, 'APPROVED'],
#  [25395, 'mfojtik', 'sttts', 1, 1597048492, 'COMMENTED'],
#  [25395, 'mfojtik', 'sttts', 1, 1597048537, 'COMMENTED'],
#  [25395, 'mfojtik', 'mfojtik', 1, 1597048843, 'COMMENTED'],
#  [25395, 'mfojtik', 'mfojtik', 1, 1597048861, 'COMMENTED'],
#  [25395, 'mfojtik', 'sttts', 1, 1597049224, 'COMMENTED'],
#  [25395, 'mfojtik', 'sttts', 1, 1597050699, 'COMMENTED'],
#  [25389, 'p0lyn0mial', 'sttts', 1, 1596789853, 'COMMENTED'],
#  [25389, 'p0lyn0mial', 'p0lyn0mial', 1, 1596805832, 'COMMENTED'],
#  [25387,
#   'openshift-cherrypick-robot',
#   'adambkaplan',
#   1,
#   1603125967,
#   'APPROVED'],
#  [25385, 'sallyom', 'soltysh', 1, 1597136814, 'CHANGES_REQUESTED'],
#  [25385, 'sallyom', 'sallyom', 1, 1597160266, 'COMMENTED'],
#  [25385, 'sallyom', 'sallyom', 1, 1597276834, 'COMMENTED'],
#  [25382, 'marun', 'sttts', 1, 1598944272, 'COMMENTED'],
#  [25382, 'marun', 'marun', 1, 1598960349, 'COMMENTED'],
#  [25381, 'marun', 'sttts', 1, 1596778753, 'COMMENTED'],
#  [25381, 'marun', 'sttts', 1, 1596778793, 'COMMENTED'],
#  [25381, 'marun', 'marun', 1, 1596823687, 'COMMENTED'],
#  [25381, 'marun', 'sttts', 1, 1597047468, 'COMMENTED'],
#  [25381, 'marun', 'marun', 1, 1597358229, 'COMMENTED'],
#  [25381, 'marun', 'sttts', 1, 1597653347, 'COMMENTED'],
#  [25381, 'marun', 'marun', 1, 1597674209, 'COMMENTED'],
#  [25362, 'cgwalters', 'abhinavdahiya', 1, 1598543707, 'COMMENTED'],
#  [25362, 'cgwalters', 'cgwalters', 1, 1598550185, 'COMMENTED'],
#  [25353, 'ecordell', 'soltysh', 1, 1598267136, 'CHANGES_REQUESTED'],
#  [25353, 'ecordell', 'ecordell', 1, 1598382866, 'COMMENTED'],
#  [25351, 'damemi', 'damemi', 1, 1603115083, 'COMMENTED'],
#  [25344, 'damemi', 'soltysh', 1, 1597144026, 'APPROVED'],
#  [25336, 'deads2k', 'smarterclayton', 1, 1595952679, 'COMMENTED'],
#  [25336, 'deads2k', 'smarterclayton', 1, 1595952722, 'COMMENTED'],
#  [25336, 'deads2k', 'smarterclayton', 1, 1595952743, 'COMMENTED'],
#  [25336, 'deads2k', 'deads2k', 1, 1595953312, 'COMMENTED'],
#  [25336, 'deads2k', 'deads2k', 1, 1595953346, 'COMMENTED'],
#  [25336, 'deads2k', 'smarterclayton', 1, 1595953536, 'COMMENTED'],
#  [25336, 'deads2k', 'wking', 1, 1595953922, 'COMMENTED'],
#  [25332, 'paulfantom', 'lilic', 1, 1596442891, 'APPROVED'],
#  [25327, 'enxebre', 'ehashman', 1, 1595871538, 'APPROVED'],
#  [25326, 'enxebre', 'ehashman', 1, 1595871518, 'APPROVED'],
#  [25323, 'ecordell', 'kevinrizza', 1, 1595843448, 'COMMENTED'],
#  [25322, 'soltysh', 'damemi', 1, 1595620600, 'APPROVED'],
#  [25322, 'soltysh', 'damemi', 30, 1595937615, 'COMMENTED'],
#  [25322, 'soltysh', 'damemi', 6, 1596150475, 'COMMENTED'],
#  [25321, 'soltysh', 'damemi', 1, 1595618137, 'APPROVED'],
#  [25320, 'damemi', 'soltysh', 1, 1595617998, 'APPROVED'],
#  [25320, 'damemi', 'damemi', 1, 1595618067, 'COMMENTED'],
#  [25319, 'soltysh', 'damemi', 1, 1595605206, 'APPROVED'],
#  [25319, 'soltysh', 'damemi', 1, 1595623906, 'APPROVED'],
#  [25315, 'deads2k', 'crawford', 1, 1598565666, 'COMMENTED'],
#  [25310, 'cynepco3hahue', 'vpickard', 3, 1596631255, 'COMMENTED'],
#  [25309, 'cynepco3hahue', 'vpickard', 3, 1596631358, 'COMMENTED'],
#  [25302, 'deads2k', 'deads2k', 1, 1595418610, 'COMMENTED'],
#  [25300, 'Joseph-Goergen', 'rtheis', 2, 1595409248, 'APPROVED'],
#  [25298, 'lilic', 'paulfantom', 1, 1595326363, 'CHANGES_REQUESTED'],
#  [25298, 'lilic', 'lilic', 1, 1595327452, 'COMMENTED'],
#  [25298, 'lilic', 'paulfantom', 1, 1595398942, 'COMMENTED'],
#  [25298, 'lilic', 'simonpasquier', 1, 1595404366, 'COMMENTED'],
#  [25298, 'lilic', 'bwplotka', 10, 1595535785, 'APPROVED'],
#  [25297, 'dmage', 'dmage', 1, 1595253836, 'COMMENTED'],
#  [25297, 'dmage', 'dmage', 1, 1595254485, 'COMMENTED'],
#  [25296, 'ingvagabund', 'soltysh', 1, 1595248802, 'APPROVED'],
#  [25291, 'deads2k', 'sanchezl', 1, 1594948060, 'APPROVED'],
#  [25291, 'deads2k', 'danwinship', 1, 1594984756, 'COMMENTED'],
#  [25291, 'deads2k', 'deads2k', 1, 1595244263, 'COMMENTED'],
#  [25291, 'deads2k', 'deads2k', 1, 1595244779, 'COMMENTED'],
#  [25291, 'deads2k', 'deads2k', 1, 1595244845, 'COMMENTED'],
#  [25291, 'deads2k', 'sanchezl', 8, 1597160687, 'APPROVED'],
#  [25283, 'soltysh', 'soltysh', 1, 1594908726, 'COMMENTED'],
#  [25283, 'soltysh', 'deads2k', 1, 1595249067, 'COMMENTED'],
#  [25283, 'soltysh', 'soltysh', 1, 1595249264, 'COMMENTED'],
#  [25282, 'sttts', 'p0lyn0mial', 1, 1594809000, 'COMMENTED'],
#  [25282, 'sttts', 'p0lyn0mial', 1, 1594809011, 'COMMENTED'],
#  [25282, 'sttts', 'p0lyn0mial', 1, 1594809040, 'COMMENTED'],
#  [25282, 'sttts', 'sttts', 1, 1594815858, 'COMMENTED'],
#  [25282, 'sttts', 'sttts', 1, 1594815983, 'COMMENTED'],
#  [25282, 'sttts', 'sttts', 1, 1594815992, 'COMMENTED'],
#  [25282, 'sttts', 'sttts', 1, 1594816057, 'COMMENTED'],
#  [25277, 'p0lyn0mial', 'tnozicka', 1, 1594708926, 'COMMENTED'],
#  [25277, 'p0lyn0mial', 'p0lyn0mial', 1, 1594709446, 'COMMENTED'],
#  [25277, 'p0lyn0mial', 'sttts', 1, 1594713274, 'COMMENTED'],
#  [25277, 'p0lyn0mial', 'sttts', 1, 1594713305, 'COMMENTED'],
#  [25277, 'p0lyn0mial', 'tnozicka', 21, 1594717278, 'COMMENTED'],
#  [25277, 'p0lyn0mial', 'sttts', 1, 1594718109, 'COMMENTED'],
#  [25259, 'p0lyn0mial', 'p0lyn0mial', 1, 1594274774, 'COMMENTED'],
#  [25259, 'p0lyn0mial', 'p0lyn0mial', 1, 1594274790, 'COMMENTED'],
#  [25257, 'p0lyn0mial', 'p0lyn0mial', 1, 1594212285, 'COMMENTED'],
#  [25253, 'damemi', 'damemi', 17, 1595350536, 'COMMENTED'],
#  [25252, 'openshift-cherrypick-robot', 'damemi', 1, 1594122549, 'COMMENTED'],
#  [25252, 'openshift-cherrypick-robot', 'soltysh', 2, 1602591628, 'APPROVED'],
#  [25252, 'openshift-cherrypick-robot', 'damemi', 9, 1602597325, 'COMMENTED'],
#  [25241, 'p0lyn0mial', 'deads2k', 1, 1594294637, 'COMMENTED'],
#  [25236, 'sttts', 'jsafrane', 1, 1596548940, 'COMMENTED'],
#  [25236, 'sttts', 'smarterclayton', 1, 1596553881, 'COMMENTED'],
#  [25236, 'sttts', 'deads2k', 1, 1596651792, 'COMMENTED'],
#  [25236, 'sttts', 'deads2k', 1, 1596651845, 'COMMENTED'],
#  [25236, 'sttts', 'deads2k', 1, 1596651895, 'COMMENTED'],
#  [25236, 'sttts', 'sttts', 1, 1597057186, 'COMMENTED'],
#  [25236, 'sttts', 'sttts', 1, 1598598593, 'COMMENTED'],
#  [25236, 'sttts', 'sttts', 1, 1598598694, 'COMMENTED'],
#  [25236, 'sttts', 'sttts', 1, 1598599805, 'COMMENTED'],
#  [25232, 'Joseph-Goergen', 'rtheis', 1, 1593627422, 'COMMENTED'],
#  [25232, 'Joseph-Goergen', 'rtheis', 1, 1593679542, 'APPROVED'],
#  [25231, 'fromanirh', 'vpickard', 24, 1593609304, 'COMMENTED'],
#  [25229, 'gabemontero', 'bparees', 1, 1593623297, 'COMMENTED'],
#  [25229, 'gabemontero', 'gabemontero', 1, 1593628075, 'COMMENTED'],
#  [25223, 'vareti', 'sttts', 1, 1594815145, 'COMMENTED'],
#  [25223, 'vareti', 'vareti', 1, 1594815354, 'COMMENTED'],
#  [25223, 'vareti', 'stlaz', 1, 1594977477, 'CHANGES_REQUESTED'],
#  [25220, 'jmcmeek', 'rtheis', 3, 1593447408, 'APPROVED'],
#  [25210, 'tnozicka', 'soltysh', 1, 1593176658, 'APPROVED'],
#  [25209, 'tnozicka', 'soltysh', 1, 1593168739, 'APPROVED'],
#  [25209, 'tnozicka', 'soltysh', 1, 1593176649, 'APPROVED'],
#  [25208, 'tnozicka', 'soltysh', 1, 1593168731, 'APPROVED'],
#  [25208, 'tnozicka', 'soltysh', 1, 1593176638, 'APPROVED'],
#  [25204, 'jottofar', 'wking', 1, 1593031433, 'APPROVED'],
#  [25204, 'jottofar', 'soltysh', 1, 1593531816, 'APPROVED'],
#  [25203, 'damemi', 'soltysh', 1, 1593530269, 'APPROVED'],
#  [25199, 'sttts', 'p0lyn0mial', 1, 1592978575, 'COMMENTED'],
#  [25199, 'sttts', 'p0lyn0mial', 1, 1592978705, 'COMMENTED'],
#  [25199, 'sttts', 'p0lyn0mial', 1, 1592978783, 'COMMENTED'],
#  [25199, 'sttts', 'p0lyn0mial', 1, 1592978835, 'COMMENTED'],
#  [25199, 'sttts', 'p0lyn0mial', 1, 1592978889, 'COMMENTED'],
#  [25199, 'sttts', 'sttts', 1, 1592978930, 'COMMENTED'],
#  [25199, 'sttts', 'p0lyn0mial', 1, 1592978937, 'COMMENTED'],
#  [25199, 'sttts', 'sttts', 1, 1592979010, 'COMMENTED'],
#  [25199, 'sttts', 'sttts', 1, 1592979017, 'COMMENTED'],
#  [25199, 'sttts', 'sttts', 1, 1592979083, 'COMMENTED'],
#  [25199, 'sttts', 'sttts', 1, 1592979286, 'COMMENTED'],
#  [25199, 'sttts', 'p0lyn0mial', 1, 1592980114, 'COMMENTED'],
#  [25199, 'sttts', 'p0lyn0mial', 1, 1592980128, 'COMMENTED'],
#  [25199, 'sttts', 'p0lyn0mial', 1, 1592980165, 'COMMENTED'],
#  [25199, 'sttts', 'sttts', 1, 1592980691, 'COMMENTED'],
#  [25199, 'sttts', 'sttts', 1, 1592980700, 'COMMENTED'],
#  [25199, 'sttts', 'sttts', 1, 1592981732, 'COMMENTED'],
#  [25199, 'sttts', 'p0lyn0mial', 1, 1593071519, 'COMMENTED'],
#  [25199, 'sttts', 'p0lyn0mial', 1, 1593071653, 'COMMENTED'],
#  [25199, 'sttts', 'p0lyn0mial', 1, 1593071706, 'COMMENTED'],
#  [25199, 'sttts', 'p0lyn0mial', 1, 1593072162, 'COMMENTED'],
#  [25199, 'sttts', 'sttts', 1, 1593074149, 'COMMENTED'],
#  [25192, 'sttts', 'mfojtik', 1, 1592982572, 'COMMENTED'],
#  [25192, 'sttts', 'mfojtik', 1, 1592982612, 'COMMENTED'],
#  [25192, 'sttts', 'mfojtik', 1, 1592982627, 'COMMENTED'],
#  [25192, 'sttts', 'mfojtik', 1, 1592982649, 'COMMENTED'],
#  [25192, 'sttts', 'mfojtik', 1, 1592982672, 'COMMENTED'],
#  [25192, 'sttts', 'sttts', 1, 1592982683, 'COMMENTED'],
#  [25192, 'sttts', 'mfojtik', 1, 1592982695, 'COMMENTED'],
#  [25192, 'sttts', 'sttts', 1, 1592982705, 'COMMENTED'],
#  [25192, 'sttts', 'sttts', 1, 1592982714, 'COMMENTED'],
#  [25192, 'sttts', 'mfojtik', 1, 1592982757, 'COMMENTED'],
#  [25192, 'sttts', 'sttts', 1, 1592982844, 'COMMENTED'],
#  [25192, 'sttts', 'mfojtik', 1, 1592982995, 'COMMENTED'],
#  [25192, 'sttts', 'sttts', 1, 1592985012, 'COMMENTED'],
#  [25192, 'sttts', 'sttts', 1, 1592985026, 'COMMENTED'],
#  [25192, 'sttts', 'sttts', 1, 1592985052, 'COMMENTED'],
#  [25192, 'sttts', 'sttts', 1, 1592985070, 'COMMENTED'],
#  [25191, 'gabemontero', 'adambkaplan', 8, 1592993801, 'CHANGES_REQUESTED'],
#  [25191, 'gabemontero', 'gabemontero', 1, 1593001243, 'COMMENTED'],
#  [25191, 'gabemontero', 'gabemontero', 1, 1593001262, 'COMMENTED'],
#  [25191, 'gabemontero', 'adambkaplan', 15, 1593172819, 'CHANGES_REQUESTED'],
#  [25191, 'gabemontero', 'gabemontero', 1, 1593172914, 'COMMENTED'],
#  [25191, 'gabemontero', 'adambkaplan', 1, 1593175281, 'APPROVED'],
#  [25185, 'stlaz', 'mfojtik', 1, 1592904854, 'COMMENTED'],
#  [25185, 'stlaz', 'stlaz', 1, 1592905763, 'COMMENTED'],
#  [25185, 'stlaz', 'sttts', 1, 1592991039, 'COMMENTED'],
#  [25172, 'hexfusion', 'tedyu', 1, 1592833861, 'COMMENTED'],
#  [25172, 'hexfusion', 'hexfusion', 1, 1592835345, 'COMMENTED'],
#  [25172, 'hexfusion', 'hexfusion', 1, 1592843746, 'COMMENTED'],
#  [25172, 'hexfusion', 'hexfusion', 1, 1592843951, 'COMMENTED'],
#  [25172, 'hexfusion', 'hexfusion', 1, 1592844209, 'COMMENTED'],
#  [25169, 'soltysh', 'soltysh', 1, 1592565419, 'COMMENTED'],
#  [25169, 'soltysh', 'stlaz', 1, 1592816811, 'COMMENTED'],
#  [25169, 'soltysh', 'stlaz', 1, 1592816863, 'COMMENTED'],
#  [25169, 'soltysh', 'stlaz', 1, 1592817707, 'COMMENTED'],
#  [25169, 'soltysh', 'soltysh', 1, 1592823270, 'COMMENTED'],
#  [25169, 'soltysh', 'soltysh', 1, 1592823450, 'COMMENTED'],
#  [25169, 'soltysh', 'stlaz', 1, 1592889698, 'COMMENTED'],
#  [25169, 'soltysh', 'soltysh', 1, 1593001713, 'COMMENTED'],
#  [25169, 'soltysh', 'stlaz', 1, 1595832744, 'COMMENTED'],
#  [25169, 'soltysh', 'stlaz', 1, 1602244749, 'COMMENTED'],
#  ...]

# %%
pr_reviews = pd.DataFrame.from_records(reviews_list)
pr_reviews.columns = ["pr_id", "pr_author", "review_author", "words_count", "submitted_at", "state"]

# %%
pr_reviews["date"] = pd.to_datetime(pr_reviews.submitted_at, unit="s")

# %%
pr_reviews_dates = pr_reviews.set_index("date").drop("submitted_at", axis=1)

# %%
print(pr_reviews_dates.shape, pr_reviews.shape)
# Out:
# (26126, 5) (26126, 7)

# %%
pr_reviews_dates
# Out:
#                      pr_id   pr_author   review_author  words_count  \
# date
# 2021-04-21 19:12:11  26096     soltysh     adambkaplan            1
# 2021-04-20 15:52:02  26093      ihcsim         deads2k            1
# 2021-04-20 16:11:04  26093      ihcsim          ihcsim            1
# 2021-04-20 17:42:34  26092     deads2k         tkashem            1
# 2021-04-20 17:48:31  26092     deads2k         tkashem            1
# ...                    ...         ...             ...          ...
# 2016-11-18 17:49:56   8258       ghost  smarterclayton            1
# 2016-11-18 17:52:10   8258       ghost         knobunc            1
# 2017-02-01 20:02:42   8094        nak3     juanvallejo            1
# 2017-02-10 13:29:49   7956  stefwalter        legionus            5
# 2017-01-20 06:56:38   7446  umairmufti         mfojtik            1
#
#                                  state
# date
# 2021-04-21 19:12:11           APPROVED
# 2021-04-20 15:52:02          COMMENTED
# 2021-04-20 16:11:04          COMMENTED
# 2021-04-20 17:42:34          COMMENTED
# 2021-04-20 17:48:31          COMMENTED
# ...                                ...
# 2016-11-18 17:49:56          COMMENTED
# 2016-11-18 17:52:10          COMMENTED
# 2017-02-01 20:02:42          COMMENTED
# 2017-02-10 13:29:49  CHANGES_REQUESTED
# 2017-01-20 06:56:38          COMMENTED
#
# [26126 rows x 5 columns]

# %% [markdown]
# #### Note: dunno why last("1Y") did not work on unsorted data, had to sort date index in order for it to work

# %%
revs_last_6_months = pr_reviews_dates.sort_index().last("1Y")
revs_last_6_months
# Out:
#                      pr_id             pr_author         review_author  \
# date
# 2021-01-04 11:13:09  25738                 stlaz                 stlaz
# 2021-01-04 12:33:44  25738                 stlaz                 stlaz
# 2021-01-06 15:48:07  25780                 stlaz                 marun
# 2021-01-07 10:38:46  25780                 stlaz                 stlaz
# 2021-01-11 10:07:40  25780                 stlaz                 sttts
# ...                    ...                   ...                   ...
# 2021-04-21 19:12:11  26096               soltysh           adambkaplan
# 2021-04-22 08:43:07  26045           ingvagabund               soltysh
# 2021-04-23 17:37:19  25931  ravisantoshgudimetla             aravindhp
# 2021-04-23 17:47:56  25931  ravisantoshgudimetla  ravisantoshgudimetla
# 2021-04-23 17:51:03  25931  ravisantoshgudimetla             aravindhp
#
#                      words_count      state
# date
# 2021-01-04 11:13:09            1  COMMENTED
# 2021-01-04 12:33:44            1  COMMENTED
# 2021-01-06 15:48:07            3  COMMENTED
# 2021-01-07 10:38:46            1  COMMENTED
# 2021-01-11 10:07:40            1  COMMENTED
# ...                          ...        ...
# 2021-04-21 19:12:11            1   APPROVED
# 2021-04-22 08:43:07            1   APPROVED
# 2021-04-23 17:37:19            1  COMMENTED
# 2021-04-23 17:47:56            1  COMMENTED
# 2021-04-23 17:51:03            1  COMMENTED
#
# [493 rows x 5 columns]

# %% [markdown]
# ### Problem: some of the PR creators are reviewing their PRs
# For example this happens here https://github.com/scikit-learn/scikit-learn/pull/19886
# -> a PR creator left some comments regarding code so that the reviewers understand it better
# ### These reviews need to be filtered out

# %%
self_reviews = revs_last_6_months.pr_author == revs_last_6_months.review_author
revs_last_6_months[~self_reviews]
# Out:
#                      pr_id             pr_author      review_author  \
# date
# 2021-01-06 15:48:07  25780                 stlaz              marun
# 2021-01-11 10:07:40  25780                 stlaz              sttts
# 2021-01-11 10:09:05  25780                 stlaz              sttts
# 2021-01-11 14:20:40  25630             e-minguez            jmencak
# 2021-01-11 15:26:14  25786              jaypoulz  ricardomaraschini
# ...                    ...                   ...                ...
# 2021-04-21 19:11:31  26091               soltysh        adambkaplan
# 2021-04-21 19:12:11  26096               soltysh        adambkaplan
# 2021-04-22 08:43:07  26045           ingvagabund            soltysh
# 2021-04-23 17:37:19  25931  ravisantoshgudimetla          aravindhp
# 2021-04-23 17:51:03  25931  ravisantoshgudimetla          aravindhp
#
#                      words_count      state
# date
# 2021-01-06 15:48:07            3  COMMENTED
# 2021-01-11 10:07:40            1  COMMENTED
# 2021-01-11 10:09:05            1  COMMENTED
# 2021-01-11 14:20:40            1   APPROVED
# 2021-01-11 15:26:14            1   APPROVED
# ...                          ...        ...
# 2021-04-21 19:11:31            1   APPROVED
# 2021-04-21 19:12:11            1   APPROVED
# 2021-04-22 08:43:07            1   APPROVED
# 2021-04-23 17:37:19            1  COMMENTED
# 2021-04-23 17:51:03            1  COMMENTED
#
# [320 rows x 5 columns]

# %% [markdown]
# ### Reviewers - data exploration

# %%
revs_last_6_months["one_vec"] = 1

# %% [markdown]
# ### Number of reviews per every reviewer

# %%
revs_last_6_months.groupby("review_author").agg({"one_vec":"sum"}).sort_values(by="one_vec").plot.bar()
# Out:
# <AxesSubplot:xlabel='review_author'>

# %% [markdown]
# ### Top 20 reviewers w.r.t. their reviews count

# %%
revs_last_6_months.groupby("review_author").agg({"one_vec":"sum"}).sort_values(by="one_vec",ascending=False)[:20].plot.bar(grid=True)
# Out:
# <AxesSubplot:xlabel='review_author'>

# %% [markdown]
# ### Type of reviews

# %%
revs_last_6_months.groupby("state").agg({"one_vec":"sum"}).sort_values(by="one_vec").plot.bar()
# Out:
# <AxesSubplot:xlabel='state'>

# %% [markdown]
# ### Comment / Approve comparisson for reviewers

# %%
approvals = revs_last_6_months["state"] == "APPROVED"
comments = revs_last_6_months["state"] == "COMMENTED"

approvers = revs_last_6_months[approvals].groupby("review_author").agg({"one_vec":"sum"})
commentators = revs_last_6_months[comments].groupby("review_author").agg({"one_vec":"sum"})

approvers.columns = ["approve_count"]
commentators.columns = ["comment_count"]

# %%
approvers.join(commentators,on="review_author",how="outer").set_index("review_author").sort_values(by="approve_count",ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='review_author'>

# %% [markdown]
# ### What we can see?
# Reviewers tend to comment more and review less (which is expected)
# and that means the recommendation metrics can be based on comments alone too

# %%
approvers.join(commentators,on="review_author",how="outer").set_index("review_author").sort_values(by="comment_count",ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='review_author'>

# %% [markdown]
# ## Make a dataframe with Time To Review times

# %%
revs_last_6_months.head()
# Out:
#                      pr_id pr_author review_author  words_count      state  \
# date
# 2021-01-04 11:13:09  25738     stlaz         stlaz            1  COMMENTED
# 2021-01-04 12:33:44  25738     stlaz         stlaz            1  COMMENTED
# 2021-01-06 15:48:07  25780     stlaz         marun            3  COMMENTED
# 2021-01-07 10:38:46  25780     stlaz         stlaz            1  COMMENTED
# 2021-01-11 10:07:40  25780     stlaz         sttts            1  COMMENTED
#
#                      one_vec
# date
# 2021-01-04 11:13:09        1
# 2021-01-04 12:33:44        1
# 2021-01-06 15:48:07        1
# 2021-01-07 10:38:46        1
# 2021-01-11 10:07:40        1

# %%
last_6_months.head()
# Out:
#                      pr_id                                              title  \
# created_at
# 2020-11-02 07:36:17  25653  Remove CSI driver installation from openshift-...
# 2020-11-02 12:55:51  25654  [release-4.5] [release-4.6] Bug 1893742: move ...
# 2020-11-02 13:28:09  25655  UPSTREAM: <carry>: Bug 1893156: include / pref...
# 2020-11-03 08:51:21  25656  Bug 1852695: CVE-2020-8559 compromised node co...
# 2020-11-03 09:14:57  25657  Bug 1852694: CVE-2020-8559 compromised node co...
#
#                                                                   body size  \
# created_at
# 2020-11-02 07:36:17  AWS EBS CSI driver is now installed by default...  XXL
# 2020-11-02 12:55:51  This is an automated cherry-pick of #25598\n\n...   XS
# 2020-11-02 13:28:09  When we want to read an instance ID from the m...   XS
# 2020-11-03 08:51:21                                        clean pick.    M
# 2020-11-03 09:14:57                                         clean pick    M
#
#                                      created_by           closed_at  \
# created_at
# 2020-11-02 07:36:17                    jsafrane 2020-11-06 16:21:39
# 2020-11-02 12:55:51  openshift-cherrypick-robot 2020-11-13 11:32:07
# 2020-11-02 13:28:09                     Fedosin 2020-11-26 00:59:31
# 2020-11-03 08:51:21                  p0lyn0mial 2020-11-19 15:17:11
# 2020-11-03 09:14:57                  p0lyn0mial 2020-12-05 18:50:03
#
#                                  closed_by           merged_at  \
# created_at
# 2020-11-02 07:36:17  openshift-merge-robot 2020-11-06 16:21:39
# 2020-11-02 12:55:51  openshift-merge-robot 2020-11-13 11:32:07
# 2020-11-02 13:28:09  openshift-merge-robot 2020-11-26 00:59:31
# 2020-11-03 08:51:21  openshift-merge-robot 2020-11-19 15:17:11
# 2020-11-03 09:14:57  openshift-merge-robot 2020-12-05 18:50:03
#
#                      changed_files_number  \
# created_at
# 2020-11-02 07:36:17                     9
# 2020-11-02 12:55:51                     1
# 2020-11-02 13:28:09                     1
# 2020-11-03 08:51:21                     4
# 2020-11-03 09:14:57                     4
#
#                                                         commits  \
# created_at
# 2020-11-02 07:36:17  [35a6aa8e94251ba3a625070e77b8af3f35408d5a]
# 2020-11-02 12:55:51  [34b3d94274b38c9fe6cc77d2b35fcb763b4f8db9]
# 2020-11-02 13:28:09  [65347c66667fe6f29819b65693221d3de56e9caa]
# 2020-11-03 08:51:21  [6d94222b1100f11a88630eb466e12b8e7fca415c]
# 2020-11-03 09:14:57  [807f37dba8731524a90b06dd437af68ea692e52e]
#
#                                                          changed_files  \
# created_at
# 2020-11-02 07:36:17  [cmd/openshift-tests/csi.go, cmd/openshift-tes...
# 2020-11-02 12:55:51                        [test/extended/util/nfs.go]
# 2020-11-02 13:28:09  [vendor/k8s.io/kubernetes/staging/src/k8s.io/l...
# 2020-11-03 08:51:21  [vendor/k8s.io/kubernetes/staging/src/k8s.io/a...
# 2020-11-03 09:14:57  [vendor/k8s.io/kubernetes/staging/src/k8s.io/a...
#
#                      counts        day  one_vec  day_of_week  hour
# created_at
# 2020-11-02 07:36:17   16776 2020-11-02        1            0     7
# 2020-11-02 12:55:51   16777 2020-11-02        1            0    12
# 2020-11-02 13:28:09   16778 2020-11-02        1            0    13
# 2020-11-03 08:51:21   16779 2020-11-03        1            1     8
# 2020-11-03 09:14:57   16780 2020-11-03        1            1     9

# %%
pulls_reviews_data = revs_last_6_months.reset_index().merge(last_6_months.reset_index(), on="pr_id")
pulls_reviews_data.columns
# Out:
# Index(['date', 'pr_id', 'pr_author', 'review_author', 'words_count', 'state',
#        'one_vec_x', 'created_at', 'title', 'body', 'size', 'created_by',
#        'closed_at', 'closed_by', 'merged_at', 'changed_files_number',
#        'commits', 'changed_files', 'counts', 'day', 'one_vec_y', 'day_of_week',
#        'hour'],
#       dtype='object')

# %% [markdown]
# ## Lets remove some of the unnecessary columns

# %%
pulls_reviews_data.drop(["day","one_vec_y","day","counts", "one_vec_x"], axis=1, inplace=True)

# %%
pulls_reviews_data.head()
# Out:
#                  date  pr_id pr_author review_author  words_count      state  \
# 0 2021-01-04 11:13:09  25738     stlaz         stlaz            1  COMMENTED
# 1 2021-01-04 12:33:44  25738     stlaz         stlaz            1  COMMENTED
# 2 2021-01-14 11:45:12  25738     stlaz       soltysh            1   APPROVED
# 3 2021-01-18 13:25:15  25738     stlaz       soltysh            2   APPROVED
# 4 2021-01-06 15:48:07  25780     stlaz         marun            3  COMMENTED
#
#            created_at                                              title  \
# 0 2020-12-03 15:30:53  Bug 1902702: fix ldap group sync tests and mov...
# 1 2020-12-03 15:30:53  Bug 1902702: fix ldap group sync tests and mov...
# 2 2020-12-03 15:30:53  Bug 1902702: fix ldap group sync tests and mov...
# 3 2020-12-03 15:30:53  Bug 1902702: fix ldap group sync tests and mov...
# 4 2021-01-06 08:14:52  Bug 1908217: server-side apply e2e: fix oauthc...
#
#                                                 body size created_by  \
# 0  /assign @soltysh \r\ncc @sallyom \r\n\r\n/hold...  XXL      stlaz
# 1  /assign @soltysh \r\ncc @sallyom \r\n\r\n/hold...  XXL      stlaz
# 2  /assign @soltysh \r\ncc @sallyom \r\n\r\n/hold...  XXL      stlaz
# 3  /assign @soltysh \r\ncc @sallyom \r\n\r\n/hold...  XXL      stlaz
# 4  When the oauthclientauthorization is created, ...    S      stlaz
#
#             closed_at              closed_by           merged_at  \
# 0 2021-01-18 15:18:25  openshift-merge-robot 2021-01-18 15:18:25
# 1 2021-01-18 15:18:25  openshift-merge-robot 2021-01-18 15:18:25
# 2 2021-01-18 15:18:25  openshift-merge-robot 2021-01-18 15:18:25
# 3 2021-01-18 15:18:25  openshift-merge-robot 2021-01-18 15:18:25
# 4 2021-01-11 19:09:50  openshift-merge-robot 2021-01-11 19:09:50
#
#    changed_files_number                                            commits  \
# 0                    75  [1903ca452fe394a1cf04e8197fc564685884f8a1, 423...
# 1                    75  [1903ca452fe394a1cf04e8197fc564685884f8a1, 423...
# 2                    75  [1903ca452fe394a1cf04e8197fc564685884f8a1, 423...
# 3                    75  [1903ca452fe394a1cf04e8197fc564685884f8a1, 423...
# 4                     1         [c56104b5e21e6810f40a0816dbd864fdf5de36d3]
#
#                                        changed_files  day_of_week  hour
# 0  [go.mod, test/extended/oauth/groupsync.go, tes...            3    15
# 1  [go.mod, test/extended/oauth/groupsync.go, tes...            3    15
# 2  [go.mod, test/extended/oauth/groupsync.go, tes...            3    15
# 3  [go.mod, test/extended/oauth/groupsync.go, tes...            3    15
# 4                 [test/extended/apiserver/apply.go]            2     8

# %% [markdown]
# ## Lets add delta time statistic
#
# To find out what was the response time of the review

# %%
pulls_reviews_data["time_delta"] = pulls_reviews_data.date - pulls_reviews_data.created_at

# %% [markdown]
# ## Boxplot of all Response Times

# %%
(pulls_reviews_data["time_delta"].dt.seconds / 3600).plot.box()
# Out:
# <AxesSubplot:>

# %%
comments = pulls_reviews_data["state"] == "COMMENTED"
approvals = pulls_reviews_data["state"] == "APPROVED"

# %% [markdown]
# ### Comment response time (hrs) boxplot

# %%
(pulls_reviews_data[ comments ]["time_delta"].dt.seconds / 3600).plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Approvals response time (hrs) boxplot

# %%
(pulls_reviews_data[ approvals ]["time_delta"].dt.seconds / 3600).plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Remove self reviewers

# %%
not_self_revs = pulls_reviews_data.pr_author != pulls_reviews_data.review_author
pulls_reviews_data = pulls_reviews_data[not_self_revs]

# %%
pulls_reviews_data.columns
# Out:
# Index(['date', 'pr_id', 'pr_author', 'review_author', 'words_count', 'state',
#        'created_at', 'title', 'body', 'size', 'created_by', 'closed_at',
#        'closed_by', 'merged_at', 'changed_files_number', 'commits',
#        'changed_files', 'day_of_week', 'hour', 'time_delta'],
#       dtype='object')

# %% [markdown]
# ### What to do next?
#
# So, I will set up my goal to have a user to user dataset (pr_author : pr_reviewer) where for each pair I will have their median (mean?) time to respond.
#
# This will be done for both train and test data (have to split it before making a user:user dataframe).
#
# Then, I will try to train NN on the PR data, with selected features:
# - pr_author
# - tokenized body and title
# - size
# - changed_files_number
# - changed_file
# - day
# - hour
# - review state ?

# %%
data = pulls_reviews_data[["pr_author", "review_author", "words_count", "state", "changed_files_number", "changed_files", "day_of_week", "hour", "time_delta"]].copy()
data["response_seconds"] = data.time_delta.dt.seconds
data.drop(["time_delta"], axis=1, inplace=True)
data
# Out:
#                 pr_author review_author  words_count      state  \
# 2                   stlaz       soltysh            1   APPROVED
# 3                   stlaz       soltysh            2   APPROVED
# 4                   stlaz         marun            3  COMMENTED
# 6                   stlaz         sttts            1  COMMENTED
# 7                   stlaz         sttts            1  COMMENTED
# ..                    ...           ...          ...        ...
# 485               deads2k         wking            1  COMMENTED
# 486               soltysh   adambkaplan            1   APPROVED
# 487           ingvagabund       soltysh            1   APPROVED
# 488  ravisantoshgudimetla     aravindhp            1  COMMENTED
# 490  ravisantoshgudimetla     aravindhp            1  COMMENTED
#
#      changed_files_number                                      changed_files  \
# 2                      75  [go.mod, test/extended/oauth/groupsync.go, tes...
# 3                      75  [go.mod, test/extended/oauth/groupsync.go, tes...
# 4                       1                 [test/extended/apiserver/apply.go]
# 6                       1                 [test/extended/apiserver/apply.go]
# 7                       1                 [test/extended/apiserver/apply.go]
# ..                    ...                                                ...
# 485                     1                          [pkg/monitor/operator.go]
# 486                     2  [test/extended/testdata/bindata.go, test/exten...
# 487                     2  [pkg/test/ginkgo/cmd_runsuite.go, pkg/test/gin...
# 488                     2  [test/extended/pods/priorityclasses.go, test/e...
# 490                     2  [test/extended/pods/priorityclasses.go, test/e...
#
#      day_of_week  hour  response_seconds
# 2              3    15             72859
# 3              3    15             78862
# 4              2     8             27195
# 6              2     8              6768
# 7              2     8              6853
# ..           ...   ...               ...
# 485            1    13             19742
# 486            2     8             38352
# 487            0    11             78177
# 488            1    16              3426
# 490            1    16              4250
#
# [318 rows x 9 columns]

# %% [markdown]
# ### Too small data? Heh, explode changed files!

# %%
data = data.explode('changed_files')
data
# Out:
#                 pr_author review_author  words_count      state  \
# 2                   stlaz       soltysh            1   APPROVED
# 2                   stlaz       soltysh            1   APPROVED
# 2                   stlaz       soltysh            1   APPROVED
# 2                   stlaz       soltysh            1   APPROVED
# 2                   stlaz       soltysh            1   APPROVED
# ..                    ...           ...          ...        ...
# 487           ingvagabund       soltysh            1   APPROVED
# 488  ravisantoshgudimetla     aravindhp            1  COMMENTED
# 488  ravisantoshgudimetla     aravindhp            1  COMMENTED
# 490  ravisantoshgudimetla     aravindhp            1  COMMENTED
# 490  ravisantoshgudimetla     aravindhp            1  COMMENTED
#
#      changed_files_number                                      changed_files  \
# 2                      75                                             go.mod
# 2                      75                   test/extended/oauth/groupsync.go
# 2                      75                        test/extended/oauth/ldap.go
# 2                      75                  test/extended/oauth/oauth_ldap.go
# 2                      75                  test/extended/testdata/bindata.go
# ..                    ...                                                ...
# 487                     2                     pkg/test/ginkgo/podanalysis.go
# 488                     2              test/extended/pods/priorityclasses.go
# 488                     2  test/extended/util/annotate/generated/zz_gener...
# 490                     2              test/extended/pods/priorityclasses.go
# 490                     2  test/extended/util/annotate/generated/zz_gener...
#
#      day_of_week  hour  response_seconds
# 2              3    15             72859
# 2              3    15             72859
# 2              3    15             72859
# 2              3    15             72859
# 2              3    15             72859
# ..           ...   ...               ...
# 487            0    11             78177
# 488            1    16              3426
# 488            1    16              3426
# 490            1    16              4250
# 490            1    16              4250
#
# [5782 rows x 9 columns]

# %% [markdown]
# ### Maybe remove changed_files number.... irrelevant now

# %%
data.drop(["changed_files_number"], axis=1, inplace=True)
data
# Out:
#                 pr_author review_author  words_count      state  \
# 2                   stlaz       soltysh            1   APPROVED
# 2                   stlaz       soltysh            1   APPROVED
# 2                   stlaz       soltysh            1   APPROVED
# 2                   stlaz       soltysh            1   APPROVED
# 2                   stlaz       soltysh            1   APPROVED
# ..                    ...           ...          ...        ...
# 487           ingvagabund       soltysh            1   APPROVED
# 488  ravisantoshgudimetla     aravindhp            1  COMMENTED
# 488  ravisantoshgudimetla     aravindhp            1  COMMENTED
# 490  ravisantoshgudimetla     aravindhp            1  COMMENTED
# 490  ravisantoshgudimetla     aravindhp            1  COMMENTED
#
#                                          changed_files  day_of_week  hour  \
# 2                                               go.mod            3    15
# 2                     test/extended/oauth/groupsync.go            3    15
# 2                          test/extended/oauth/ldap.go            3    15
# 2                    test/extended/oauth/oauth_ldap.go            3    15
# 2                    test/extended/testdata/bindata.go            3    15
# ..                                                 ...          ...   ...
# 487                     pkg/test/ginkgo/podanalysis.go            0    11
# 488              test/extended/pods/priorityclasses.go            1    16
# 488  test/extended/util/annotate/generated/zz_gener...            1    16
# 490              test/extended/pods/priorityclasses.go            1    16
# 490  test/extended/util/annotate/generated/zz_gener...            1    16
#
#      response_seconds
# 2               72859
# 2               72859
# 2               72859
# 2               72859
# 2               72859
# ..                ...
# 487             78177
# 488              3426
# 488              3426
# 490              4250
# 490              4250
#
# [5782 rows x 8 columns]

# %% [markdown]
# ### Encode features

# %%
from sklearn import preprocessing

for col in ["pr_author", "review_author", "state", "changed_files"]:
    enc = preprocessing.LabelEncoder()
    data[col] = enc.fit_transform(data[col])

data
# Out:
#      pr_author  review_author  words_count  state  changed_files  day_of_week  \
# 2           36             43            1      0             23            3
# 2           36             43            1      0            114            3
# 2           36             43            1      0            115            3
# 2           36             43            1      0            116            3
# 2           36             43            1      0            154            3
# ..         ...            ...          ...    ...            ...          ...
# 487         17             43            1      0             63            0
# 488         29              7            1      2            126            1
# 488         29              7            1      2            309            1
# 490         29              7            1      2            126            1
# 490         29              7            1      2            309            1
#
#      hour  response_seconds
# 2      15             72859
# 2      15             72859
# 2      15             72859
# 2      15             72859
# 2      15             72859
# ..    ...               ...
# 487    11             78177
# 488    16              3426
# 488    16              3426
# 490    16              4250
# 490    16              4250
#
# [5782 rows x 8 columns]

# %% [markdown]
# ### Split data

# %% [markdown]
# ### TODO: make stratuum split so that distribution of reviewers is equal in train and test
# ### Edit: split date before exploding files! So that unseen PRs appear in test

# %%
y = data.review_author
X = data.drop(["review_author"], axis=1)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,)

# %% [markdown]
# ## Try some models !

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### KNN ?

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=1)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9671564390665515

# %% [markdown]
# #### RandomForests

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=20)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.986171132238548

# %% [markdown]
# ### But this is incorrect evaulation!
#
# Test prediction should be based only on information known in time of recommendation.
#
# In case of PR reviewer recommendation, I don't know features like words_count, state, response time and etc.!

# %%
y = data.review_author
X = data.drop(["review_author", "words_count", "state", "response_seconds"], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,)

clf = KNeighborsClassifier(n_neighbors=1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("KNN acc:", accuracy_score(y_test, y_pred))

clf = RandomForestClassifier(max_depth=20)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("RF acc:", accuracy_score(y_test, y_pred))
# Out:
# KNN acc: 0.8496110630942092
# RF acc: 0.8945548833189283

# %% [markdown]
# However, I am loosing valuable information from dropped features.
# What is the solution?
#
# ### Neural Network embeddings!

# %%
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
num_of_revs = len(data.review_author.unique())
num_of_revs
# Out:
# 50

# %%
y = keras.utils.to_categorical(data.review_author)
X = data.drop(["review_author"], axis=1)

## Too big values compared to other features
## by doing this accuracy is >0.9 (by not doing this the nn didn't even have 0.7)
X.response_seconds = X.response_seconds / X.response_seconds.max()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,)

# %%
model = Sequential()

model.add(Dense(8))
model.add(Dense(100, activation="relu"))
model.add(Dense(num_of_revs, activation="softmax"))

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

model.fit(X_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# 145/145 [==============================] - 0s 520us/step - loss: 71.9336 - accuracy: 0.3842
# Epoch 2/200
# 145/145 [==============================] - 0s 633us/step - loss: 2.4822 - accuracy: 0.5783
# Epoch 3/200
# 145/145 [==============================] - 0s 537us/step - loss: 2.3416 - accuracy: 0.6361
# Epoch 4/200
# 145/145 [==============================] - 0s 535us/step - loss: 1.7990 - accuracy: 0.6590
# Epoch 5/200
# 145/145 [==============================] - 0s 598us/step - loss: 2.4968 - accuracy: 0.6675
# Epoch 6/200
# 145/145 [==============================] - 0s 578us/step - loss: 1.8636 - accuracy: 0.6840
# Epoch 7/200
# 145/145 [==============================] - 0s 545us/step - loss: 1.1549 - accuracy: 0.7476
# Epoch 8/200
# 145/145 [==============================] - 0s 544us/step - loss: 1.0551 - accuracy: 0.7606
# Epoch 9/200
# 145/145 [==============================] - 0s 520us/step - loss: 1.5254 - accuracy: 0.7337
# Epoch 10/200
# 145/145 [==============================] - 0s 526us/step - loss: 1.7883 - accuracy: 0.7242
# Epoch 11/200
# 145/145 [==============================] - 0s 575us/step - loss: 2.0600 - accuracy: 0.7037
# Epoch 12/200
# 145/145 [==============================] - 0s 564us/step - loss: 1.0461 - accuracy: 0.7658
# Epoch 13/200
# 145/145 [==============================] - 0s 571us/step - loss: 1.1443 - accuracy: 0.7851
# Epoch 14/200
# 145/145 [==============================] - 0s 551us/step - loss: 1.3017 - accuracy: 0.7701
# Epoch 15/200
# 145/145 [==============================] - 0s 581us/step - loss: 0.8540 - accuracy: 0.8219
# Epoch 16/200
# 145/145 [==============================] - 0s 581us/step - loss: 0.9219 - accuracy: 0.8043
# Epoch 17/200
# 145/145 [==============================] - 0s 550us/step - loss: 0.8569 - accuracy: 0.8095
# Epoch 18/200
# 145/145 [==============================] - 0s 549us/step - loss: 0.7847 - accuracy: 0.8193
# Epoch 19/200
# 145/145 [==============================] - 0s 557us/step - loss: 0.7891 - accuracy: 0.8160
# Epoch 20/200
# 145/145 [==============================] - 0s 532us/step - loss: 0.8548 - accuracy: 0.8121
# Epoch 21/200
# 145/145 [==============================] - 0s 557us/step - loss: 1.2706 - accuracy: 0.7956
# Epoch 22/200
# 145/145 [==============================] - 0s 552us/step - loss: 1.0293 - accuracy: 0.7965
# Epoch 23/200
# 145/145 [==============================] - 0s 567us/step - loss: 0.7053 - accuracy: 0.8158
# Epoch 24/200
# 145/145 [==============================] - 0s 559us/step - loss: 1.0211 - accuracy: 0.8041
# Epoch 25/200
# 145/145 [==============================] - 0s 529us/step - loss: 0.8768 - accuracy: 0.8113
# Epoch 26/200
# 145/145 [==============================] - 0s 568us/step - loss: 0.7459 - accuracy: 0.8365
# Epoch 27/200
# 145/145 [==============================] - 0s 587us/step - loss: 0.7520 - accuracy: 0.8225
# Epoch 28/200
# 145/145 [==============================] - 0s 547us/step - loss: 0.8051 - accuracy: 0.8384
# Epoch 29/200
# 145/145 [==============================] - 0s 562us/step - loss: 1.2613 - accuracy: 0.8275
# Epoch 30/200
# 145/145 [==============================] - 0s 556us/step - loss: 0.6125 - accuracy: 0.8427
# Epoch 31/200
# 145/145 [==============================] - 0s 560us/step - loss: 0.8791 - accuracy: 0.8276
# Epoch 32/200
# 145/145 [==============================] - 0s 550us/step - loss: 0.6583 - accuracy: 0.8429
# Epoch 33/200
# 145/145 [==============================] - 0s 540us/step - loss: 0.5469 - accuracy: 0.8507
# Epoch 34/200
# 145/145 [==============================] - 0s 562us/step - loss: 0.6438 - accuracy: 0.8463
# Epoch 35/200
# 145/145 [==============================] - 0s 547us/step - loss: 0.6749 - accuracy: 0.8500
# Epoch 36/200
# 145/145 [==============================] - 0s 546us/step - loss: 0.6245 - accuracy: 0.8387
# Epoch 37/200
# 145/145 [==============================] - 0s 556us/step - loss: 0.6505 - accuracy: 0.8508
# Epoch 38/200
# 145/145 [==============================] - 0s 540us/step - loss: 0.6714 - accuracy: 0.8510
# Epoch 39/200
# 145/145 [==============================] - 0s 584us/step - loss: 0.8155 - accuracy: 0.8346
# Epoch 40/200
# 145/145 [==============================] - 0s 561us/step - loss: 1.1359 - accuracy: 0.8251
# Epoch 41/200
# 145/145 [==============================] - 0s 565us/step - loss: 0.5475 - accuracy: 0.8581
# Epoch 42/200
# 145/145 [==============================] - 0s 576us/step - loss: 0.5799 - accuracy: 0.8509
# Epoch 43/200
# 145/145 [==============================] - 0s 573us/step - loss: 0.6265 - accuracy: 0.8408
# Epoch 44/200
# 145/145 [==============================] - 0s 571us/step - loss: 0.4715 - accuracy: 0.8629
# Epoch 45/200
# 145/145 [==============================] - 0s 571us/step - loss: 0.6424 - accuracy: 0.8495
# Epoch 46/200
# 145/145 [==============================] - 0s 558us/step - loss: 0.7511 - accuracy: 0.8420
# Epoch 47/200
# 145/145 [==============================] - 0s 545us/step - loss: 0.5364 - accuracy: 0.8544
# Epoch 48/200
# 145/145 [==============================] - 0s 571us/step - loss: 0.6279 - accuracy: 0.8487
# Epoch 49/200
# 145/145 [==============================] - 0s 547us/step - loss: 0.5222 - accuracy: 0.8597
# Epoch 50/200
# 145/145 [==============================] - 0s 544us/step - loss: 0.5137 - accuracy: 0.8612
# Epoch 51/200
# 145/145 [==============================] - 0s 567us/step - loss: 0.5379 - accuracy: 0.8527
# Epoch 52/200
# 145/145 [==============================] - 0s 567us/step - loss: 0.5129 - accuracy: 0.8487
# Epoch 53/200
# 145/145 [==============================] - 0s 556us/step - loss: 0.4533 - accuracy: 0.8707
# Epoch 54/200
# 145/145 [==============================] - 0s 542us/step - loss: 0.4449 - accuracy: 0.8729
# Epoch 55/200
# 145/145 [==============================] - 0s 540us/step - loss: 0.8512 - accuracy: 0.8685
# Epoch 56/200
# 145/145 [==============================] - 0s 535us/step - loss: 0.5516 - accuracy: 0.8553
# Epoch 57/200
# 145/145 [==============================] - 0s 550us/step - loss: 0.8205 - accuracy: 0.8293
# Epoch 58/200
# 145/145 [==============================] - 0s 543us/step - loss: 0.5025 - accuracy: 0.8578
# Epoch 59/200
# 145/145 [==============================] - 0s 543us/step - loss: 0.5242 - accuracy: 0.8706
# Epoch 60/200
# 145/145 [==============================] - 0s 570us/step - loss: 0.6605 - accuracy: 0.8555
# Epoch 61/200
# 145/145 [==============================] - 0s 618us/step - loss: 0.4583 - accuracy: 0.8618
# Epoch 62/200
# 145/145 [==============================] - 0s 620us/step - loss: 0.5899 - accuracy: 0.8598
# Epoch 63/200
# 145/145 [==============================] - 0s 707us/step - loss: 0.4597 - accuracy: 0.8724
# Epoch 64/200
# 145/145 [==============================] - 0s 687us/step - loss: 0.4393 - accuracy: 0.8762
# Epoch 65/200
# 145/145 [==============================] - 0s 607us/step - loss: 0.4842 - accuracy: 0.8696
# Epoch 66/200
# 145/145 [==============================] - 0s 561us/step - loss: 0.4851 - accuracy: 0.8795
# Epoch 67/200
# 145/145 [==============================] - 0s 525us/step - loss: 0.4556 - accuracy: 0.8785
# Epoch 68/200
# 145/145 [==============================] - 0s 541us/step - loss: 0.4733 - accuracy: 0.8831
# Epoch 69/200
# 145/145 [==============================] - 0s 570us/step - loss: 0.5367 - accuracy: 0.8710
# Epoch 70/200
# 145/145 [==============================] - 0s 539us/step - loss: 0.4510 - accuracy: 0.8785
# Epoch 71/200
# 145/145 [==============================] - 0s 538us/step - loss: 0.3876 - accuracy: 0.8738
# Epoch 72/200
# 145/145 [==============================] - 0s 562us/step - loss: 0.4933 - accuracy: 0.8818
# Epoch 73/200
# 145/145 [==============================] - 0s 566us/step - loss: 0.5058 - accuracy: 0.8679
# Epoch 74/200
# 145/145 [==============================] - 0s 565us/step - loss: 0.4233 - accuracy: 0.8916
# Epoch 75/200
# 145/145 [==============================] - 0s 565us/step - loss: 0.3663 - accuracy: 0.8851
# Epoch 76/200
# 145/145 [==============================] - 0s 556us/step - loss: 0.3712 - accuracy: 0.8854
# Epoch 77/200
# 145/145 [==============================] - 0s 572us/step - loss: 0.3692 - accuracy: 0.8868
# Epoch 78/200
# 145/145 [==============================] - 0s 552us/step - loss: 0.4870 - accuracy: 0.8750
# Epoch 79/200
# 145/145 [==============================] - 0s 539us/step - loss: 0.3483 - accuracy: 0.8875
# Epoch 80/200
# 145/145 [==============================] - 0s 549us/step - loss: 0.3706 - accuracy: 0.8969
# Epoch 81/200
# 145/145 [==============================] - 0s 553us/step - loss: 0.3729 - accuracy: 0.8943
# Epoch 82/200
# 145/145 [==============================] - 0s 622us/step - loss: 0.4406 - accuracy: 0.8825
# Epoch 83/200
# 145/145 [==============================] - 0s 645us/step - loss: 0.3292 - accuracy: 0.8887
# Epoch 84/200
# 145/145 [==============================] - 0s 600us/step - loss: 0.5300 - accuracy: 0.8824
# Epoch 85/200
# 145/145 [==============================] - 0s 627us/step - loss: 0.3387 - accuracy: 0.9026
# Epoch 86/200
# 145/145 [==============================] - 0s 753us/step - loss: 0.3734 - accuracy: 0.8921
# Epoch 87/200
# 145/145 [==============================] - 0s 688us/step - loss: 0.3313 - accuracy: 0.8900
# Epoch 88/200
# 145/145 [==============================] - 0s 658us/step - loss: 0.3395 - accuracy: 0.8945
# Epoch 89/200
# 145/145 [==============================] - 0s 627us/step - loss: 0.3374 - accuracy: 0.9011
# Epoch 90/200
# 145/145 [==============================] - 0s 660us/step - loss: 0.3233 - accuracy: 0.8962
# Epoch 91/200
# 145/145 [==============================] - 0s 653us/step - loss: 0.3211 - accuracy: 0.9086
# Epoch 92/200
# 145/145 [==============================] - 0s 601us/step - loss: 0.3126 - accuracy: 0.8987
# Epoch 93/200
# 145/145 [==============================] - 0s 570us/step - loss: 0.3052 - accuracy: 0.9010
# Epoch 94/200
# 145/145 [==============================] - 0s 531us/step - loss: 0.2943 - accuracy: 0.9072
# Epoch 95/200
# 145/145 [==============================] - 0s 550us/step - loss: 0.3510 - accuracy: 0.8994
# Epoch 96/200
# 145/145 [==============================] - 0s 539us/step - loss: 0.2870 - accuracy: 0.9133
# Epoch 97/200
# 145/145 [==============================] - 0s 558us/step - loss: 0.2718 - accuracy: 0.9058
# Epoch 98/200
# 145/145 [==============================] - 0s 540us/step - loss: 0.3269 - accuracy: 0.8931
# Epoch 99/200
# 145/145 [==============================] - 0s 526us/step - loss: 0.2998 - accuracy: 0.8964
# Epoch 100/200
# 145/145 [==============================] - 0s 527us/step - loss: 0.2931 - accuracy: 0.8987
# Epoch 101/200
# 145/145 [==============================] - 0s 546us/step - loss: 0.3422 - accuracy: 0.8955
# Epoch 102/200
# 145/145 [==============================] - 0s 542us/step - loss: 0.2624 - accuracy: 0.9151
# Epoch 103/200
# 145/145 [==============================] - 0s 536us/step - loss: 0.2842 - accuracy: 0.9074
# Epoch 104/200
# 145/145 [==============================] - 0s 526us/step - loss: 0.2469 - accuracy: 0.9121
# Epoch 105/200
# 145/145 [==============================] - 0s 545us/step - loss: 0.2882 - accuracy: 0.8983
# Epoch 106/200
# 145/145 [==============================] - 0s 550us/step - loss: 0.2489 - accuracy: 0.9131
# Epoch 107/200
# 145/145 [==============================] - 0s 548us/step - loss: 0.2489 - accuracy: 0.9159
# Epoch 108/200
# 145/145 [==============================] - 0s 550us/step - loss: 0.2704 - accuracy: 0.9050
# Epoch 109/200
# 145/145 [==============================] - 0s 575us/step - loss: 0.2441 - accuracy: 0.9170
# Epoch 110/200
# 145/145 [==============================] - 0s 551us/step - loss: 0.2806 - accuracy: 0.9142
# Epoch 111/200
# 145/145 [==============================] - 0s 538us/step - loss: 0.2437 - accuracy: 0.9181
# Epoch 112/200
# 145/145 [==============================] - 0s 530us/step - loss: 0.2774 - accuracy: 0.9091
# Epoch 113/200
# 145/145 [==============================] - 0s 551us/step - loss: 0.2742 - accuracy: 0.9125
# Epoch 114/200
# 145/145 [==============================] - 0s 533us/step - loss: 0.3030 - accuracy: 0.9126
# Epoch 115/200
# 145/145 [==============================] - 0s 541us/step - loss: 0.2455 - accuracy: 0.9119
# Epoch 116/200
# 145/145 [==============================] - 0s 531us/step - loss: 0.2424 - accuracy: 0.9128
# Epoch 117/200
# 145/145 [==============================] - 0s 550us/step - loss: 0.2305 - accuracy: 0.9213
# Epoch 118/200
# 145/145 [==============================] - 0s 568us/step - loss: 0.2262 - accuracy: 0.9165
# Epoch 119/200
# 145/145 [==============================] - 0s 553us/step - loss: 0.2599 - accuracy: 0.9085
# Epoch 120/200
# 145/145 [==============================] - 0s 545us/step - loss: 0.2251 - accuracy: 0.9126
# Epoch 121/200
# 145/145 [==============================] - 0s 589us/step - loss: 0.2215 - accuracy: 0.9207
# Epoch 122/200
# 145/145 [==============================] - 0s 558us/step - loss: 0.2198 - accuracy: 0.9234
# Epoch 123/200
# 145/145 [==============================] - 0s 569us/step - loss: 0.2435 - accuracy: 0.9165
# Epoch 124/200
# 145/145 [==============================] - 0s 590us/step - loss: 0.2328 - accuracy: 0.9186
# Epoch 125/200
# 145/145 [==============================] - 0s 554us/step - loss: 0.2185 - accuracy: 0.9157
# Epoch 126/200
# 145/145 [==============================] - 0s 535us/step - loss: 0.2114 - accuracy: 0.9156
# Epoch 127/200
# 145/145 [==============================] - 0s 542us/step - loss: 0.2115 - accuracy: 0.9222
# Epoch 128/200
# 145/145 [==============================] - 0s 555us/step - loss: 0.2047 - accuracy: 0.9176
# Epoch 129/200
# 145/145 [==============================] - 0s 538us/step - loss: 0.2155 - accuracy: 0.9187
# Epoch 130/200
# 145/145 [==============================] - 0s 543us/step - loss: 0.2214 - accuracy: 0.9244
# Epoch 131/200
# 145/145 [==============================] - 0s 525us/step - loss: 0.2358 - accuracy: 0.9201
# Epoch 132/200
# 145/145 [==============================] - 0s 565us/step - loss: 0.2032 - accuracy: 0.9321
# Epoch 133/200
# 145/145 [==============================] - 0s 537us/step - loss: 0.2219 - accuracy: 0.9128
# Epoch 134/200
# 145/145 [==============================] - 0s 562us/step - loss: 0.2050 - accuracy: 0.9233
# Epoch 135/200
# 145/145 [==============================] - 0s 558us/step - loss: 0.2058 - accuracy: 0.9191
# Epoch 136/200
# 145/145 [==============================] - 0s 538us/step - loss: 0.2020 - accuracy: 0.9270
# Epoch 137/200
# 145/145 [==============================] - 0s 559us/step - loss: 0.2031 - accuracy: 0.9271
# Epoch 138/200
# 145/145 [==============================] - 0s 667us/step - loss: 0.1974 - accuracy: 0.9251
# Epoch 139/200
# 145/145 [==============================] - 0s 659us/step - loss: 0.1930 - accuracy: 0.9272
# Epoch 140/200
# 145/145 [==============================] - 0s 643us/step - loss: 0.1999 - accuracy: 0.9249
# Epoch 141/200
# 145/145 [==============================] - 0s 670us/step - loss: 0.1903 - accuracy: 0.9262
# Epoch 142/200
# 145/145 [==============================] - 0s 641us/step - loss: 0.2059 - accuracy: 0.9235
# Epoch 143/200
# 145/145 [==============================] - 0s 532us/step - loss: 0.2211 - accuracy: 0.9106
# Epoch 144/200
# 145/145 [==============================] - 0s 551us/step - loss: 0.1973 - accuracy: 0.9264
# Epoch 145/200
# 145/145 [==============================] - 0s 541us/step - loss: 0.1773 - accuracy: 0.9340
# Epoch 146/200
# 145/145 [==============================] - 0s 569us/step - loss: 0.1891 - accuracy: 0.9229
# Epoch 147/200
# 145/145 [==============================] - 0s 535us/step - loss: 0.1957 - accuracy: 0.9172
# Epoch 148/200
# 145/145 [==============================] - 0s 581us/step - loss: 0.1960 - accuracy: 0.9272
# Epoch 149/200
# 145/145 [==============================] - 0s 542us/step - loss: 0.1903 - accuracy: 0.9224
# Epoch 150/200
# 145/145 [==============================] - 0s 536us/step - loss: 0.2024 - accuracy: 0.9280
# Epoch 151/200
# 145/145 [==============================] - 0s 539us/step - loss: 0.1865 - accuracy: 0.9262
# Epoch 152/200
# 145/145 [==============================] - 0s 530us/step - loss: 0.1824 - accuracy: 0.9301
# Epoch 153/200
# 145/145 [==============================] - 0s 553us/step - loss: 0.1885 - accuracy: 0.9300
# Epoch 154/200
# 145/145 [==============================] - 0s 550us/step - loss: 0.2162 - accuracy: 0.9142
# Epoch 155/200
# 145/145 [==============================] - 0s 532us/step - loss: 0.1901 - accuracy: 0.9236
# Epoch 156/200
# 145/145 [==============================] - 0s 535us/step - loss: 0.1782 - accuracy: 0.9231
# Epoch 157/200
# 145/145 [==============================] - 0s 542us/step - loss: 0.1874 - accuracy: 0.9157
# Epoch 158/200
# 145/145 [==============================] - 0s 572us/step - loss: 0.1820 - accuracy: 0.9270
# Epoch 159/200
# 145/145 [==============================] - 0s 542us/step - loss: 0.1732 - accuracy: 0.9273
# Epoch 160/200
# 145/145 [==============================] - 0s 537us/step - loss: 0.1692 - accuracy: 0.9280
# Epoch 161/200
# 145/145 [==============================] - 0s 540us/step - loss: 0.1707 - accuracy: 0.9266
# Epoch 162/200
# 145/145 [==============================] - 0s 553us/step - loss: 0.1609 - accuracy: 0.9372
# Epoch 163/200
# 145/145 [==============================] - 0s 546us/step - loss: 0.1775 - accuracy: 0.9294
# Epoch 164/200
# 145/145 [==============================] - 0s 529us/step - loss: 0.1694 - accuracy: 0.9331
# Epoch 165/200
# 145/145 [==============================] - 0s 554us/step - loss: 0.1655 - accuracy: 0.9318
# Epoch 166/200
# 145/145 [==============================] - 0s 594us/step - loss: 0.1789 - accuracy: 0.9292
# Epoch 167/200
# 145/145 [==============================] - 0s 629us/step - loss: 0.1637 - accuracy: 0.9314
# Epoch 168/200
# 145/145 [==============================] - 0s 628us/step - loss: 0.1664 - accuracy: 0.9364
# Epoch 169/200
# 145/145 [==============================] - 0s 667us/step - loss: 0.1563 - accuracy: 0.9371
# Epoch 170/200
# 145/145 [==============================] - 0s 667us/step - loss: 0.2101 - accuracy: 0.9251
# Epoch 171/200
# 145/145 [==============================] - 0s 681us/step - loss: 0.1767 - accuracy: 0.9350
# Epoch 172/200
# 145/145 [==============================] - 0s 698us/step - loss: 0.1516 - accuracy: 0.9304
# Epoch 173/200
# 145/145 [==============================] - 0s 695us/step - loss: 0.1617 - accuracy: 0.9346
# Epoch 174/200
# 145/145 [==============================] - 0s 679us/step - loss: 0.1619 - accuracy: 0.9318
# Epoch 175/200
# 145/145 [==============================] - 0s 676us/step - loss: 0.1549 - accuracy: 0.9422
# Epoch 176/200
# 145/145 [==============================] - 0s 658us/step - loss: 0.1531 - accuracy: 0.9331
# Epoch 177/200
# 145/145 [==============================] - 0s 654us/step - loss: 0.1540 - accuracy: 0.9353
# Epoch 178/200
# 145/145 [==============================] - 0s 683us/step - loss: 0.1564 - accuracy: 0.9290
# Epoch 179/200
# 145/145 [==============================] - 0s 683us/step - loss: 0.1642 - accuracy: 0.9335
# Epoch 180/200
# 145/145 [==============================] - 0s 705us/step - loss: 0.1499 - accuracy: 0.9356
# Epoch 181/200
# 145/145 [==============================] - 0s 674us/step - loss: 0.1528 - accuracy: 0.9347
# Epoch 182/200
# 145/145 [==============================] - 0s 712us/step - loss: 0.1710 - accuracy: 0.9310
# Epoch 183/200
# 145/145 [==============================] - 0s 681us/step - loss: 0.1414 - accuracy: 0.9409
# Epoch 184/200
# 145/145 [==============================] - 0s 735us/step - loss: 0.1572 - accuracy: 0.9356
# Epoch 185/200
# 145/145 [==============================] - 0s 718us/step - loss: 0.1569 - accuracy: 0.9372
# Epoch 186/200
# 145/145 [==============================] - 0s 704us/step - loss: 0.1522 - accuracy: 0.9424
# Epoch 187/200
# 145/145 [==============================] - 0s 715us/step - loss: 0.1518 - accuracy: 0.9357
# Epoch 188/200
# 145/145 [==============================] - 0s 715us/step - loss: 0.1539 - accuracy: 0.9339
# Epoch 189/200
# 145/145 [==============================] - 0s 707us/step - loss: 0.1334 - accuracy: 0.9431
# Epoch 190/200
# 145/145 [==============================] - 0s 659us/step - loss: 0.1644 - accuracy: 0.9374
# Epoch 191/200
# 145/145 [==============================] - 0s 655us/step - loss: 0.1598 - accuracy: 0.9353
# Epoch 192/200
# 145/145 [==============================] - 0s 645us/step - loss: 0.1618 - accuracy: 0.9372
# Epoch 193/200
# 145/145 [==============================] - 0s 669us/step - loss: 0.1607 - accuracy: 0.9371
# Epoch 194/200
# 145/145 [==============================] - 0s 662us/step - loss: 0.1432 - accuracy: 0.9374
# Epoch 195/200
# 145/145 [==============================] - 0s 698us/step - loss: 0.1336 - accuracy: 0.9419
# Epoch 196/200
# 145/145 [==============================] - 0s 696us/step - loss: 0.1591 - accuracy: 0.9414
# Epoch 197/200
# 145/145 [==============================] - 0s 703us/step - loss: 0.1446 - accuracy: 0.9400
# Epoch 198/200
# 145/145 [==============================] - 0s 711us/step - loss: 0.1967 - accuracy: 0.9274
# Epoch 199/200
# 145/145 [==============================] - 0s 675us/step - loss: 0.1417 - accuracy: 0.9382
# Epoch 200/200
# 145/145 [==============================] - 0s 691us/step - loss: 0.1433 - accuracy: 0.9366

# %%
X_train.response_seconds / X_train.response_seconds.max()
# Out:
# 214    0.881025
# 260    0.876554
# 3      0.930349
# 280    0.048593
# 447    0.188578
#          ...
# 126    0.823337
# 447    0.188578
# 447    0.188578
# 447    0.188578
# 447    0.188578
# Name: response_seconds, Length: 4625, dtype: float64
